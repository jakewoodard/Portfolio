# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt

SALARY_CAP = 47000
PLAYER_POP = pd.read_csv("week9_data.csv")
name = "LAMAR JACKSON"
PLAYER_POP.loc[PLAYER_POP['NAME'] == name]['DK salary'].values[0]

duplicates = PLAYER_POP.duplicated(subset=['NAME'], keep=False)
PLAYER_POP.drop_duplicates(subset=['NAME'], inplace=True)
for i in duplicates:
    if i == True:
        print(i)

# an average lineup scores            120
# an average winning lineup scores    137
# average trny winning lineup         148
# average best trny lineup scores     188
# perfect lineup scores               246

# %%
# Define the size of the population and tournament size
POPULATION_SIZE   = 500
TOURNAMENT_SIZE   = 5
MUTATION_RATE     = 0.1
N_ITERATIONS      = 5

# Define the position groups we need
qb = PLAYER_POP[(PLAYER_POP["POS"] == "QB") & (PLAYER_POP["DK salary"] >= 4800)]
rb = PLAYER_POP[(PLAYER_POP["POS"] == "RB") & (PLAYER_POP["DK salary"] > 4000)]
wr = PLAYER_POP[(PLAYER_POP["POS"] == "WR") & (PLAYER_POP["DK salary"] > 3400)]
te = PLAYER_POP[(PLAYER_POP["POS"] == "TE") & (PLAYER_POP["RTG"] >= 70)]
flex = PLAYER_POP[(PLAYER_POP["POS"].isin(["RB", "WR", "TE"])) & (PLAYER_POP["DK salary"] > 4000)]

# Sort the position groups by descending order of DK salary
qb = qb.sort_values("DK salary", ascending=False)
rb = rb.sort_values("DK salary", ascending=False)
wr = wr.sort_values("DK salary", ascending=False)
te = te.sort_values("DK salary", ascending=False)
flex = flex.sort_values("DK salary", ascending=False)

# Create a population of potential solutions
i = 0
population = []
lineup_points = []
while i < POPULATION_SIZE:

    # Select one player from each position group and one additional player from the flex group
    selected_players = []
    
    # Select QB, no need to check
    selected_players.append(qb.iloc[random.randint(0, len(qb)-1)])
    
    # Select the RBs, ensuring that they are different players
    rb1 = rb.iloc[random.randint(0, len(rb)-1)]
    selected_players.append(rb1)
    
    rb2 = rb.iloc[random.randint(0, len(rb)-1)]
    while rb2.equals(rb1):
        rb2 = rb.iloc[random.randint(0, len(rb)-1)]
    selected_players.append(rb2)

    # Select the WRs, ensuring that they are different players
    wr1 = wr.iloc[random.randint(0, len(wr)-1)]
    selected_players.append(wr1)
    
    wr2 = wr.iloc[random.randint(0, len(wr)-1)]
    while wr2.equals(wr1):
        wr2 = wr.iloc[random.randint(0, len(wr)-1)]
    selected_players.append(wr2)

    wr3 = wr.iloc[random.randint(0, len(wr)-1)]
    while wr3.equals(wr1) or wr3.equals(wr2):
        wr3 = wr.iloc[random.randint(0, len(wr)-1)]
    selected_players.append(wr3)

    # Select TE, no need to check
    te1 = te.iloc[random.randint(0, len(te)-1)]
    selected_players.append(te1)

    # Select FLEX, most checking here
    rb_wr_te = flex.iloc[random.randint(0, len(flex)-1)]
    while rb_wr_te.equals(rb1) or rb_wr_te.equals(rb2) or rb_wr_te.equals(wr1) or rb_wr_te.equals(wr2) or rb_wr_te.equals(wr3) or rb_wr_te.equals(te1):
        rb_wr_te = flex.iloc[random.randint(0, len(flex)-1)]
    selected_players.append(rb_wr_te)

    # Check if the total salary is under the cap
    total_salary = sum(selected_player["DK salary"] for selected_player in selected_players)
    
    if total_salary <= 47000 & total_salary >= 45000:    
        # Print the selected lineup
        #print("Lineup {}: \n".format(i))
        i += 1
        p = 0
        for selected_player in selected_players:
            #print(selected_player["NAME"], selected_player["POS"], selected_player["DK salary"])
            p += selected_player["DK points"]
        #print("\n")
        population.append(selected_players)
        lineup_points.append(p)

avg_points_init_pop = np.mean(lineup_points)
print("AVG LINEUP SCORE OF INIT POPULATION: " + str(avg_points_init_pop))
# Out:
# Lineup 0:
#
# TOM BRADY QB 7600
# JEFF WILSON RB 5000
# AUSTIN EKELER RB 7600
# KEENAN ALLEN WR 7000
# TIM PATRICK WR 4900
# DEEBO SAMUEL WR 7400
# IAN THOMAS TE 2500
# JAVONTE WILLIAMS RB 5000
#
#
# Lineup 1:
#
# JUSTIN HERBERT QB 7300
# D'ANDRE SWIFT RB 6800
# JAMES ROBINSON RB 6200
# TIM PATRICK WR 4900
# DEEBO SAMUEL WR 7400
# LAVISKA SHENAULT WR 4600
# GERALD EVERETT TE 2600
# DARREL WILLIAMS RB 5400
#
#
# Lineup 2:
#
# LAMAR JACKSON QB 7800
# JEREMY MCNICHOLS RB 5500
# MICHAEL CARTER RB 5600
# JAYLEN WADDLE WR 5500
# TYLER LOCKETT WR 6500
# AMARI COOPER WR 6200
# HAYDEN HURST TE 2800
# MARQUISE BROWN WR 6700
#
#
# Lineup 3:
#
# TOM BRADY QB 7600
# MYLES GASKIN RB 6000
# DARREL WILLIAMS RB 5400
# DK METCALF WR 6800
# VAN JEFFERSON WR 4100
# ZACH PASCAL WR 4500
# DALTON SCHULTZ TE 5000
# MARVIN JONES WR 5800
#
#
# Lineup 4:
#
# MATTHEW STAFFORD QB 7000
# ELIJAH MITCHELL RB 5700
# JAMES CONNER RB 6300
# SAMMY WATKINS WR 4300
# DJ MOORE WR 6300
# KALIF RAYMOND WR 4900
# MARK ANDREWS TE 5700
# DEVONTA FREEMAN RB 5000
#
#
# Lineup 5:
#
# TREVOR SIEMIAN QB 5200
# D'ERNEST JOHNSON RB 4700
# EZEKIEL ELLIOTT RB 7000
# DK METCALF WR 6800
# MECOLE HARDMAN WR 3900
# COOPER KUPP WR 9500
# IAN THOMAS TE 2500
# COURTLAND SUTTON WR 5600
#
#
# Lineup 6:
#
# TEDDY BRIDGEWATER QB 5500
# D'ANDRE SWIFT RB 6800
# ANTONIO GIBSON RB 5500
# ROBBY ANDERSON WR 4400
# MARVIN JONES WR 5800
# CHRISTIAN KIRK WR 5500
# MIKE GESICKI TE 4900
# DK METCALF WR 6800
#
#
# Lineup 7:
#
# TREVOR LAWRENCE QB 5300
# DALVIN COOK RB 8000
# AJ DILLON RB 4800
# TY HILTON WR 4700
# MICHAEL GALLUP WR 4000
# MIKE EVANS WR 6900
# PAT FREIERMUTH TE 3900
# TERRY MCLAURIN WR 7600
#
#
# Lineup 8:
#
# JOSH ALLEN QB 7900
# JOSH JACOBS RB 6200
# MARK INGRAM RB 4500
# DIONTAE JOHNSON WR 6800
# CHRISTIAN KIRK WR 5500
# TRE'QUAN SMITH WR 4300
# TAYSOM HILL TE 5200
# CORDARRELLE PATTERSON RB 6600
#
#
# Lineup 9:
#
# KIRK COUSINS QB 6100
# ADRIAN PETERSON RB 4900
# NAJEE HARRIS RB 7900
# MARVIN JONES WR 5800
# MIKE EVANS WR 6900
# LAVISKA SHENAULT WR 4600
# DAN ARNOLD TE 3500
# CHRISTIAN KIRK WR 5500
#
#
# Lineup 10:
#
# MIKE WHITE QB 5100
# JONATHAN TAYLOR RB 8100
# AUSTIN EKELER RB 7600
# TIM PATRICK WR 4900
# DEEBO SAMUEL WR 7400
# COLE BEASLEY WR 5200
# TOMMY TREMBLE TE 2500
# ENO BENJAMIN RB 4400
#
#
# Lineup 11:
#
# KIRK COUSINS QB 6100
# D'ANDRE SWIFT RB 6800
# ELIJAH MITCHELL RB 5700
# JUSTIN JEFFERSON WR 7700
# AMARI COOPER WR 6200
# MECOLE HARDMAN WR 3900
# TJ HOCKENSON TE 5500
# BRANDON AIYUK WR 4700
#
#
# Lineup 12:
#
# JARED GOFF QB 5200
# CHRISTIAN MCCAFFREY RB 8400
# KENYAN DRAKE RB 5100
# JUSTIN JEFFERSON WR 7700
# CHRIS GODWIN WR 7100
# ELIJAH MOORE WR 4700
# IAN THOMAS TE 2500
# JAMES CONNER RB 6300
#
#
# Lineup 13:
#
# KIRK COUSINS QB 6100
# JEREMY MCNICHOLS RB 5500
# JORDAN HOWARD RB 4900
# AJ GREEN WR 4600
# MICHAEL GALLUP WR 4000
# DAVANTE ADAMS WR 7900
# HUNTER HENRY TE 4100
# JONATHAN TAYLOR RB 8100
#
#
# Lineup 14:
#
# MATT RYAN QB 6000
# AUSTIN EKELER RB 7600
# ENO BENJAMIN RB 4400
# MICHAEL PITTMAN WR 6300
# MARVIN JONES WR 5800
# STEFON DIGGS WR 7500
# TYLER CONKLIN TE 3400
# RASHOD BATEMAN WR 4200
#
#
# Lineup 15:
#
# COLT MCCOY QB 5000
# KENYAN DRAKE RB 5100
# D'ANDRE SWIFT RB 6800
# MARQUEZ CALLAWAY WR 5100
# MECOLE HARDMAN WR 3900
# DIONTAE JOHNSON WR 6800
# DARREN WALLER TE 6300
# JOSH JACOBS RB 6200
#
#
# Lineup 16:
#
# JOSH ALLEN QB 7900
# ALEX COLLINS RB 5200
# ENO BENJAMIN RB 4400
# AJ BROWN WR 7800
# COURTLAND SUTTON WR 5600
# SAMMY WATKINS WR 4300
# TOMMY SWEENEY TE 2600
# DEEBO SAMUEL WR 7400
#
#
# Lineup 17:
#
# DEREK CARR QB 6000
# JALEN RICHARD RB 4200
# NAJEE HARRIS RB 7900
# TYREEK HILL WR 7700
# SAMMY WATKINS WR 4300
# TRE'QUAN SMITH WR 4300
# DAWSON KNOX TE 4500
# DARREN WALLER TE 6300
#
#
# Lineup 18:
#
# JOSH ALLEN QB 7900
# JD MCKISSIC RB 5200
# LEONARD FOURNETTE RB 6100
# CHRIS GODWIN WR 7100
# MICHAEL PITTMAN WR 6300
# EMMANUEL SANDERS WR 5700
# ALBERT OKWUEGBUNAM TE 3300
# JEFF WILSON RB 5000
#
#
# Lineup 19:
#
# JIMMY GAROPPOLO QB 5500
# JEREMY MCNICHOLS RB 5500
# ELIJAH MITCHELL RB 5700
# DAVANTE ADAMS WR 7900
# CEEDEE LAMB WR 7000
# COURTLAND SUTTON WR 5600
# MIKE GESICKI TE 4900
# KALIF RAYMOND WR 4900
#
#
# Lineup 20:
#
# CASE KEENUM QB 4900
# NYHEIM HINES RB 5000
# D'ANDRE SWIFT RB 6800
# LAVISKA SHENAULT WR 4600
# AJ BROWN WR 7800
# KEENAN ALLEN WR 7000
# NOAH FANT TE 4300
# AMARI COOPER WR 6200
#
#
# Lineup 21:
#
# TUA TAGOVAILOA QB 5600
# RHAMONDRE STEVENSON RB 4500
# ALEX COLLINS RB 5200
# KEENAN ALLEN WR 7000
# DEEBO SAMUEL WR 7400
# JAYLEN WADDLE WR 5500
# ADAM TRAUTMAN TE 3000
# CEEDEE LAMB WR 7000
#
#
# Lineup 22:
#
# MATTHEW STAFFORD QB 7000
# CHRISTIAN MCCAFFREY RB 8400
# KENNY GAINWELL RB 4700
# KEENAN ALLEN WR 7000
# TRE'QUAN SMITH WR 4300
# MIKE EVANS WR 6900
# AUSTIN HOOPER TE 2800
# TJ HOCKENSON TE 5500
#
#
# Lineup 23:
#
# DAK PRESCOTT QB 6900
# ELIJAH MITCHELL RB 5700
# JOSH JACOBS RB 6200
# COOPER KUPP WR 9500
# TIM PATRICK WR 4900
# MICHAEL GALLUP WR 4000
# TYLER HIGBEE TE 4000
# MARVIN JONES WR 5800
#
#
# Lineup 24:
#
# DAK PRESCOTT QB 6900
# DARRELL HENDERSON RB 6400
# TONY POLLARD RB 4600
# JAMISON CROWDER WR 4800
# COOPER KUPP WR 9500
# TAJAE SHARPE WR 3900
# WILL DISSLY TE 2500
# CORDARRELLE PATTERSON RB 6600
#
#
# Lineup 25:
#
# RYAN TANNEHILL QB 6200
# ELIJAH MITCHELL RB 5700
# NYHEIM HINES RB 5000
# TIM PATRICK WR 4900
# AMARI COOPER WR 6200
# DAVANTE ADAMS WR 7900
# TJ HOCKENSON TE 5500
# TAYSOM HILL TE 5200
#
#
# Lineup 26:
#
# TREVOR LAWRENCE QB 5300
# MELVIN GORDON RB 5300
# AARON JONES RB 6900
# CHRISTIAN KIRK WR 5500
# DJ MOORE WR 6300
# BRYAN EDWARDS WR 4200
# DALLAS GOEDERT TE 4700
# CEEDEE LAMB WR 7000
#
#
# Lineup 27:
#
# JOSH ALLEN QB 7900
# ALEXANDER MATTISON RB 4500
# AUSTIN EKELER RB 7600
# DIONTAE JOHNSON WR 6800
# ADAM THIELEN WR 6700
# ADAM HUMPHRIES WR 3500
# MARK ANDREWS TE 5700
# GIOVANI BERNARD RB 4300
#
#
# Lineup 28:
#
# PATRICK MAHOMES QB 7200
# DEVONTA FREEMAN RB 5000
# AARON JONES RB 6900
# VAN JEFFERSON WR 4100
# COOPER KUPP WR 9500
# KEENAN ALLEN WR 7000
# GERALD EVERETT TE 2600
# GIOVANI BERNARD RB 4300
#
#
# Lineup 29:
#
# TEDDY BRIDGEWATER QB 5500
# LEONARD FOURNETTE RB 6100
# BRANDON BOLDEN RB 4400
# AMARI COOPER WR 6200
# KEENAN ALLEN WR 7000
# ELIJAH MOORE WR 4700
# MIKE GESICKI TE 4900
# AJ BROWN WR 7800
#
#
# Lineup 30:
#
# MATTHEW STAFFORD QB 7000
# ANTONIO GIBSON RB 5500
# DEEJAY DALLAS RB 4100
# TIM PATRICK WR 4900
# ELIJAH MOORE WR 4700
# TYREEK HILL WR 7700
# KYLE PITTS TE 5800
# AARON JONES RB 6900
#
#
# Lineup 31:
#
# TOM BRADY QB 7600
# JAMES ROBINSON RB 6200
# ANTONIO GIBSON RB 5500
# AJ GREEN WR 4600
# DAVANTE ADAMS WR 7900
# COLE BEASLEY WR 5200
# OJ HOWARD TE 2700
# CHRISTIAN KIRK WR 5500
#
#
# Lineup 32:
#
# MATTHEW STAFFORD QB 7000
# CHRISTIAN MCCAFFREY RB 8400
# CARLOS HYDE RB 5000
# BRANDON AIYUK WR 4700
# OLAMIDE ZACCHEAUS WR 4400
# MIKE EVANS WR 6900
# TYLER CONKLIN TE 3400
# DK METCALF WR 6800
#
#
# Lineup 33:
#
# TEDDY BRIDGEWATER QB 5500
# DARRELL HENDERSON RB 6400
# MELVIN GORDON RB 5300
# RUSSELL GAGE WR 5000
# MIKE WILLIAMS WR 6600
# MARVIN JONES WR 5800
# HUNTER HENRY TE 4100
# DAVANTE ADAMS WR 7900
#
#
# Lineup 34:
#
# DEREK CARR QB 6000
# JAMES CONNER RB 6300
# RHAMONDRE STEVENSON RB 4500
# DEONTE HARRIS WR 4000
# AJ BROWN WR 7800
# JUSTIN JEFFERSON WR 7700
# TJ HOCKENSON TE 5500
# JAKOBI MEYERS WR 4800
#
#
# Lineup 35:
#
# JARED GOFF QB 5200
# AARON JONES RB 6900
# JAMES ROBINSON RB 6200
# COREY DAVIS WR 4900
# AJ BROWN WR 7800
# MICHAEL PITTMAN WR 6300
# ALBERT OKWUEGBUNAM TE 3300
# ZACH ERTZ TE 4600
#
#
# Lineup 36:
#
# TUA TAGOVAILOA QB 5600
# ZACK MOSS RB 5100
# KENNY GAINWELL RB 4700
# QUEZ WATKINS WR 3600
# JERRY JEUDY WR 5300
# TERRY MCLAURIN WR 7600
# DARREN WALLER TE 6300
# CHRISTIAN MCCAFFREY RB 8400
#
#
# Lineup 37:
#
# PATRICK MAHOMES QB 7200
# ALEXANDER MATTISON RB 4500
# DARREL WILLIAMS RB 5400
# RANDALL COBB WR 4300
# COOPER KUPP WR 9500
# TAJAE SHARPE WR 3900
# TOMMY TREMBLE TE 2500
# NAJEE HARRIS RB 7900
#
#
# Lineup 38:
#
# JIMMY GAROPPOLO QB 5500
# AUSTIN EKELER RB 7600
# ADRIAN PETERSON RB 4900
# LAVISKA SHENAULT WR 4600
# DEVONTA SMITH WR 5900
# HUNTER RENFROW WR 5100
# DALTON SCHULTZ TE 5000
# CHRISTIAN MCCAFFREY RB 8400
#
#
# Lineup 39:
#
# TOM BRADY QB 7600
# DEEJAY DALLAS RB 4100
# SONY MICHEL RB 4300
# TYLER LOCKETT WR 6500
# MIKE WILLIAMS WR 6600
# DK METCALF WR 6800
# GEORGE KITTLE TE 6000
# TY HILTON WR 4700
#
#
# Lineup 40:
#
# DAK PRESCOTT QB 6900
# JAMES ROBINSON RB 6200
# JAVONTE WILLIAMS RB 5000
# MIKE EVANS WR 6900
# TIM PATRICK WR 4900
# DEEBO SAMUEL WR 7400
# MIKE GESICKI TE 4900
# BRANDON BOLDEN RB 4400
#
#
# Lineup 41:
#
# LAMAR JACKSON QB 7800
# JONATHAN TAYLOR RB 8100
# JAMES CONNER RB 6300
# RUSSELL GAGE WR 5000
# JAMAL AGNEW WR 4500
# JALEN REAGOR WR 3500
# TYLER CONKLIN TE 3400
# MIKE WILLIAMS WR 6600
#
#
# Lineup 42:
#
# AARON RODGERS QB 7100
# JAMES ROBINSON RB 6200
# JORDAN HOWARD RB 4900
# DEEBO SAMUEL WR 7400
# JERRY JEUDY WR 5300
# LAVISKA SHENAULT WR 4600
# TJ HOCKENSON TE 5500
# GEORGE KITTLE TE 6000
#
#
# Lineup 43:
#
# JALEN HURTS QB 6500
# NAJEE HARRIS RB 7900
# JOSH JACOBS RB 6200
# CHRIS GODWIN WR 7100
# CEEDEE LAMB WR 7000
# JAKOBI MEYERS WR 4800
# HARRISON BRYANT TE 2500
# JEFF WILSON RB 5000
# Lineup 44:
#
# PATRICK MAHOMES QB 7200
# DEVIN SINGLETARY RB 4700
# BOSTON SCOTT RB 4900
# DAVANTE ADAMS WR 7900
# ADAM HUMPHRIES WR 3500
# DIONTAE JOHNSON WR 6800
# DARREN WALLER TE 6300
# MELVIN GORDON RB 5300
#
#
# Lineup 45:
#
# JUSTIN HERBERT QB 7300
# ANTONIO GIBSON RB 5500
# JAMES CONNER RB 6300
# COREY DAVIS WR 4900
# COURTLAND SUTTON WR 5600
# JERRY JEUDY WR 5300
# TRAVIS KELCE TE 6900
# COLE BEASLEY WR 5200
#
#
# Lineup 46:
#
# LAMAR JACKSON QB 7800
# JD MCKISSIC RB 5200
# ANTONIO GIBSON RB 5500
# TRE'QUAN SMITH WR 4300
# MARVIN JONES WR 5800
# DK METCALF WR 6800
# TRAVIS KELCE TE 6900
# TY HILTON WR 4700
#
#
# Lineup 47:
#
# JARED GOFF QB 5200
# CHUBA HUBBARD RB 5400
# NAJEE HARRIS RB 7900
# JAMES WASHINGTON WR 3500
# DAVANTE ADAMS WR 7900
# EMMANUEL SANDERS WR 5700
# TAYSOM HILL TE 5200
# KYLE PITTS TE 5800
#
#
# Lineup 48:
#
# JOSH ALLEN QB 7900
# MYLES GASKIN RB 6000
# JONATHAN TAYLOR RB 8100
# COREY DAVIS WR 4900
# DK METCALF WR 6800
# JERRY JEUDY WR 5300
# ALBERT OKWUEGBUNAM TE 3300
# NOAH FANT TE 4300
#
#
# Lineup 49:
#
# JOSH ALLEN QB 7900
# EZEKIEL ELLIOTT RB 7000
# MELVIN GORDON RB 5300
# CEEDEE LAMB WR 7000
# MARQUISE BROWN WR 6700
# QUEZ WATKINS WR 3600
# HUNTER HENRY TE 4100
# RUSSELL GAGE WR 5000
#
#
# Lineup 50:
#
# MIKE WHITE QB 5100
# JAMES ROBINSON RB 6200
# DEEJAY DALLAS RB 4100
# HUNTER RENFROW WR 5100
# MIKE WILLIAMS WR 6600
# KEENAN ALLEN WR 7000
# DALTON SCHULTZ TE 5000
# LEONARD FOURNETTE RB 6100
#
#
# Lineup 51:
#
# LAMAR JACKSON QB 7800
# NAJEE HARRIS RB 7900
# TONY POLLARD RB 4600
# TIM PATRICK WR 4900
# RUSSELL GAGE WR 5000
# HUNTER RENFROW WR 5100
# TJ HOCKENSON TE 5500
# AMARI COOPER WR 6200
#
#
# Lineup 52:
#
# LAMAR JACKSON QB 7800
# JAVONTE WILLIAMS RB 5000
# MIKE DAVIS RB 4600
# MIKE EVANS WR 6900
# CEEDEE LAMB WR 7000
# MICHAEL PITTMAN WR 6300
# ZACH ERTZ TE 4600
# JAKOBI MEYERS WR 4800
#
#
# Lineup 53:
#
# TREVOR LAWRENCE QB 5300
# BOSTON SCOTT RB 4900
# D'ANDRE SWIFT RB 6800
# DIONTAE JOHNSON WR 6800
# KEENAN ALLEN WR 7000
# STEFON DIGGS WR 7500
# WILL DISSLY TE 2500
# AMARI COOPER WR 6200
#
#
# Lineup 54:
#
# COLT MCCOY QB 5000
# EZEKIEL ELLIOTT RB 7000
# JALEN RICHARD RB 4200
# TAJAE SHARPE WR 3900
# RUSSELL GAGE WR 5000
# COOPER KUPP WR 9500
# IAN THOMAS TE 2500
# JONATHAN TAYLOR RB 8100
#
#
# Lineup 55:
#
# PATRICK MAHOMES QB 7200
# EZEKIEL ELLIOTT RB 7000
# MYLES GASKIN RB 6000
# DEVONTA SMITH WR 5900
# ADAM HUMPHRIES WR 3500
# STEFON DIGGS WR 7500
# JACK DOYLE TE 3100
# RUSSELL GAGE WR 5000
#
#
# Lineup 56:
#
# AARON RODGERS QB 7100
# AUSTIN EKELER RB 7600
# JAMES CONNER RB 6300
# MARQUEZ VALDESSCANTLING WR 3500
# MIKE WILLIAMS WR 6600
# AMONRA ST BROWN WR 3800
# TYLER HIGBEE TE 4000
# MICHAEL PITTMAN WR 6300
#
#
# Lineup 57:
#
# CARSON WENTZ QB 5900
# JAMES CONNER RB 6300
# ELIJAH MITCHELL RB 5700
# COOPER KUPP WR 9500
# TIM PATRICK WR 4900
# DK METCALF WR 6800
# GERALD EVERETT TE 2600
# JERRY JEUDY WR 5300
#
#
# Lineup 58:
#
# AARON RODGERS QB 7100
# JORDAN HOWARD RB 4900
# MARK INGRAM RB 4500
# MICHAEL PITTMAN WR 6300
# COURTLAND SUTTON WR 5600
# DAVANTE ADAMS WR 7900
# KYLE PITTS TE 5800
# KALIF RAYMOND WR 4900
#
#
# Lineup 59:
#
# DAK PRESCOTT QB 6900
# LEONARD FOURNETTE RB 6100
# DALVIN COOK RB 8000
# CEEDEE LAMB WR 7000
# DEEBO SAMUEL WR 7400
# LAVISKA SHENAULT WR 4600
# DURHAM SMYTHE TE 2500
# TRAVIS HOMER RB 4500
#
#
# Lineup 60:
#
# RUSSELL WILSON QB 6700
# JEREMY MCNICHOLS RB 5500
# JOSH JACOBS RB 6200
# MIKE EVANS WR 6900
# JAMISON CROWDER WR 4800
# JAKOBI MEYERS WR 4800
# GEORGE KITTLE TE 6000
# EMMANUEL SANDERS WR 5700
#
#
# Lineup 61:
#
# COOPER RUSH QB 4800
# JORDAN HOWARD RB 4900
# D'ANDRE SWIFT RB 6800
# MIKE WILLIAMS WR 6600
# CHRISTIAN KIRK WR 5500
# JUSTIN JEFFERSON WR 7700
# TJ HOCKENSON TE 5500
# JARVIS LANDRY WR 5200
#
#
# Lineup 62:
#
# JOSH ALLEN QB 7900
# EZEKIEL ELLIOTT RB 7000
# DEEJAY DALLAS RB 4100
# TERRY MCLAURIN WR 7600
# TIM PATRICK WR 4900
# MIKE WILLIAMS WR 6600
# PAT FREIERMUTH TE 3900
# MIKE DAVIS RB 4600
#
#
# Lineup 63:
#
# JARED GOFF QB 5200
# DEVIN SINGLETARY RB 4700
# JAMES ROBINSON RB 6200
# DK METCALF WR 6800
# COOPER KUPP WR 9500
# CEDRICK WILSON WR 3500
# ZACH ERTZ TE 4600
# D'ERNEST JOHNSON RB 4700
#
#
# Lineup 64:
#
# LAMAR JACKSON QB 7800
# JD MCKISSIC RB 5200
# DALVIN COOK RB 8000
# TYLER LOCKETT WR 6500
# MARQUISE BROWN WR 6700
# KALIF RAYMOND WR 4900
# JUWAN JOHNSON TE 2500
# DEVONTA FREEMAN RB 5000
#
#
# Lineup 65:
#
# TEDDY BRIDGEWATER QB 5500
# ZACK MOSS RB 5100
# JONATHAN TAYLOR RB 8100
# KALIF RAYMOND WR 4900
# COOPER KUPP WR 9500
# TAJAE SHARPE WR 3900
# TYLER CONKLIN TE 3400
# AMARI COOPER WR 6200
#
#
# Lineup 66:
#
# JIMMY GAROPPOLO QB 5500
# D'ANDRE SWIFT RB 6800
# RHAMONDRE STEVENSON RB 4500
# DONOVAN PEOPLESJONES WR 4800
# MICHAEL PITTMAN WR 6300
# MIKE WILLIAMS WR 6600
# TOMMY SWEENEY TE 2600
# JONATHAN TAYLOR RB 8100
#
#
# Lineup 67:
#
# DAK PRESCOTT QB 6900
# AUSTIN EKELER RB 7600
# JORDAN HOWARD RB 4900
# RUSSELL GAGE WR 5000
# TAJAE SHARPE WR 3900
# DAVANTE ADAMS WR 7900
# MO ALIECOX TE 3100
# TYREEK HILL WR 7700
#
#
# Lineup 68:
#
# JOSH ALLEN QB 7900
# JAVONTE WILLIAMS RB 5000
# MELVIN GORDON RB 5300
# DONOVAN PEOPLESJONES WR 4800
# MARVIN JONES WR 5800
# TERRY MCLAURIN WR 7600
# JUWAN JOHNSON TE 2500
# JUSTIN JEFFERSON WR 7700
#
#
# Lineup 69:
#
# MATTHEW STAFFORD QB 7000
# AJ DILLON RB 4800
# D'ANDRE SWIFT RB 6800
# MICHAEL GALLUP WR 4000
# DEEBO SAMUEL WR 7400
# SAMMY WATKINS WR 4300
# JARED COOK TE 3200
# COOPER KUPP WR 9500
#
#
# Lineup 70:
#
# MAC JONES QB 5300
# D'ANDRE SWIFT RB 6800
# JOSH JACOBS RB 6200
# AJ BROWN WR 7800
# EMMANUEL SANDERS WR 5700
# MARVIN JONES WR 5800
# AUSTIN HOOPER TE 2800
# AMARI COOPER WR 6200
#
#
# Lineup 71:
#
# MAC JONES QB 5300
# ADRIAN PETERSON RB 4900
# MIKE DAVIS RB 4600
# DAVANTE ADAMS WR 7900
# BRYAN EDWARDS WR 4200
# TERRY MCLAURIN WR 7600
# ALBERT OKWUEGBUNAM TE 3300
# DEEBO SAMUEL WR 7400
#
#
# Lineup 72:
#
# DAK PRESCOTT QB 6900
# JEREMY MCNICHOLS RB 5500
# TREY SERMON RB 4300
# JAKOBI MEYERS WR 4800
# TYREEK HILL WR 7700
# MARQUISE BROWN WR 6700
# RICKY SEALSJONES TE 3700
# MICHAEL CARTER RB 5600
#
#
# Lineup 73:
#
# JALEN HURTS QB 6500
# AUSTIN EKELER RB 7600
# MICHAEL CARTER RB 5600
# TERRY MCLAURIN WR 7600
# QUEZ WATKINS WR 3600
# JAMISON CROWDER WR 4800
# JACK DOYLE TE 3100
# AJ BROWN WR 7800
#
#
# Lineup 74:
#
# TEDDY BRIDGEWATER QB 5500
# AUSTIN EKELER RB 7600
# MARK INGRAM RB 4500
# TIM PATRICK WR 4900
# TAJAE SHARPE WR 3900
# AJ BROWN WR 7800
# DAWSON KNOX TE 4500
# TYLER LOCKETT WR 6500
#
#
# Lineup 75:
#
# TEDDY BRIDGEWATER QB 5500
# SONY MICHEL RB 4300
# TONY POLLARD RB 4600
# TERRY MCLAURIN WR 7600
# TYREEK HILL WR 7700
# DONOVAN PEOPLESJONES WR 4800
# TRAVIS KELCE TE 6900
# MICHAEL CARTER RB 5600
#
#
# Lineup 76:
#
# JALEN HURTS QB 6500
# MYLES GASKIN RB 6000
# NAJEE HARRIS RB 7900
# MICHAEL GALLUP WR 4000
# JAMAL AGNEW WR 4500
# MIKE WILLIAMS WR 6600
# DALLAS GOEDERT TE 4700
# JEFF WILSON RB 5000
#
#
# Lineup 77:
#
# TOM BRADY QB 7600
# JONATHAN TAYLOR RB 8100
# AJ DILLON RB 4800
# DJ MOORE WR 6300
# MIKE EVANS WR 6900
# JAMAL AGNEW WR 4500
# IAN THOMAS TE 2500
# DEVONTA SMITH WR 5900
#
#
# Lineup 78:
#
# LAMAR JACKSON QB 7800
# JOSH JACOBS RB 6200
# JEREMY MCNICHOLS RB 5500
# CHRISTIAN KIRK WR 5500
# JUSTIN JEFFERSON WR 7700
# ELIJAH MOORE WR 4700
# HUNTER HENRY TE 4100
# HUNTER RENFROW WR 5100
#
#
# Lineup 79:
#
# LAMAR JACKSON QB 7800
# ZACK MOSS RB 5100
# NYHEIM HINES RB 5000
# CHRIS GODWIN WR 7100
# KEENAN ALLEN WR 7000
# ELIJAH MOORE WR 4700
# TAYSOM HILL TE 5200
# DEVIN SINGLETARY RB 4700
#
#
# Lineup 80:
#
# KIRK COUSINS QB 6100
# ALEX COLLINS RB 5200
# JONATHAN TAYLOR RB 8100
# DONOVAN PEOPLESJONES WR 4800
# DK METCALF WR 6800
# NELSON AGHOLOR WR 4000
# GEORGE KITTLE TE 6000
# JALEN RICHARD RB 4200
#
#
# Lineup 81:
#
# JARED GOFF QB 5200
# ELIJAH MITCHELL RB 5700
# MIKE DAVIS RB 4600
# TAJAE SHARPE WR 3900
# TY HILTON WR 4700
# COOPER KUPP WR 9500
# DALTON SCHULTZ TE 5000
# CORDARRELLE PATTERSON RB 6600
#
#
# Lineup 82:
#
# BAKER MAYFIELD QB 5400
# DARRELL HENDERSON RB 6400
# KENYAN DRAKE RB 5100
# SAMMY WATKINS WR 4300
# MARQUISE BROWN WR 6700
# MIKE EVANS WR 6900
# DAWSON KNOX TE 4500
# JUSTIN JEFFERSON WR 7700
#
#
# Lineup 83:
#
# AARON RODGERS QB 7100
# NAJEE HARRIS RB 7900
# AARON JONES RB 6900
# CHRIS GODWIN WR 7100
# TIM PATRICK WR 4900
# MICHAEL GALLUP WR 4000
# TOMMY SWEENEY TE 2600
# D'ERNEST JOHNSON RB 4700
#
#
# Lineup 84:
#
# MATT RYAN QB 6000
# D'ERNEST JOHNSON RB 4700
# DEVONTA FREEMAN RB 5000
# DAVANTE ADAMS WR 7900
# EMMANUEL SANDERS WR 5700
# STEFON DIGGS WR 7500
# RICKY SEALSJONES TE 3700
# LE'VEON BELL RB 4700
#
#
# Lineup 85:
#
# RUSSELL WILSON QB 6700
# ALEX COLLINS RB 5200
# AUSTIN EKELER RB 7600
# ADAM THIELEN WR 6700
# JAKOBI MEYERS WR 4800
# JALEN GUYTON WR 3600
# TJ HOCKENSON TE 5500
# KENYAN DRAKE RB 5100
#
#
# Lineup 86:
#
# JIMMY GAROPPOLO QB 5500
# AJ DILLON RB 4800
# CORDARRELLE PATTERSON RB 6600
# AMONRA ST BROWN WR 3800
# CEEDEE LAMB WR 7000
# DK METCALF WR 6800
# GEORGE KITTLE TE 6000
# LEONARD FOURNETTE RB 6100
#
#
# Lineup 87:
#
# CASE KEENUM QB 4900
# TRAVIS HOMER RB 4500
# LE'VEON BELL RB 4700
# MIKE EVANS WR 6900
# DK METCALF WR 6800
# JUSTIN JEFFERSON WR 7700
# JACK DOYLE TE 3100
# CORDARRELLE PATTERSON RB 6600
#
#
# Lineup 88:
#
# JUSTIN HERBERT QB 7300
# AUSTIN EKELER RB 7600
# JD MCKISSIC RB 5200
# ADAM HUMPHRIES WR 3500
# TERRY MCLAURIN WR 7600
# TIM PATRICK WR 4900
# DARREN WALLER TE 6300
# JALEN RICHARD RB 4200
#
#
# Lineup 89:
#
# DEREK CARR QB 6000
# CHRISTIAN MCCAFFREY RB 8400
# MICHAEL CARTER RB 5600
# KEENAN ALLEN WR 7000
# QUEZ WATKINS WR 3600
# CEEDEE LAMB WR 7000
# HAYDEN HURST TE 2800
# MIKE WILLIAMS WR 6600
# Lineup 90:
#
# MAC JONES QB 5300
# JD MCKISSIC RB 5200
# JAMES CONNER RB 6300
# TYREEK HILL WR 7700
# COREY DAVIS WR 4900
# KEENAN ALLEN WR 7000
# MIKE GESICKI TE 4900
# EMMANUEL SANDERS WR 5700
#
#
# Lineup 91:
#
# TREVOR SIEMIAN QB 5200
# MICHAEL CARTER RB 5600
# DEVIN SINGLETARY RB 4700
# DJ MOORE WR 6300
# RUSSELL GAGE WR 5000
# STEFON DIGGS WR 7500
# MIKE GESICKI TE 4900
# GEORGE KITTLE TE 6000
#
#
# Lineup 92:
#
# DEREK CARR QB 6000
# AUSTIN EKELER RB 7600
# CARLOS HYDE RB 5000
# AJ BROWN WR 7800
# RONDALE MOORE WR 4400
# STEFON DIGGS WR 7500
# ALBERT OKWUEGBUNAM TE 3300
# JAVONTE WILLIAMS RB 5000
#
#
# Lineup 93:
#
# JOSH ALLEN QB 7900
# LEONARD FOURNETTE RB 6100
# GIOVANI BERNARD RB 4300
# AJ BROWN WR 7800
# COURTLAND SUTTON WR 5600
# JAKOBI MEYERS WR 4800
# NOAH FANT TE 4300
# AMARI COOPER WR 6200
#
#
# Lineup 94:
#
# MIKE WHITE QB 5100
# JOSH JACOBS RB 6200
# GIOVANI BERNARD RB 4300
# DIONTAE JOHNSON WR 6800
# KALIF RAYMOND WR 4900
# COOPER KUPP WR 9500
# ALBERT OKWUEGBUNAM TE 3300
# AARON JONES RB 6900
#
#
# Lineup 95:
#
# MIKE WHITE QB 5100
# EZEKIEL ELLIOTT RB 7000
# BOSTON SCOTT RB 4900
# DEVONTA SMITH WR 5900
# DAVANTE ADAMS WR 7900
# AJ BROWN WR 7800
# OJ HOWARD TE 2700
# MARK ANDREWS TE 5700
#
#
# Lineup 96:
#
# KIRK COUSINS QB 6100
# D'ANDRE SWIFT RB 6800
# MYLES GASKIN RB 6000
# CHRIS GODWIN WR 7100
# JARVIS LANDRY WR 5200
# MARQUISE BROWN WR 6700
# IAN THOMAS TE 2500
# JOSH JACOBS RB 6200
#
#
# Lineup 97:
#
# JOSH ALLEN QB 7900
# RHAMONDRE STEVENSON RB 4500
# CARLOS HYDE RB 5000
# BRYAN EDWARDS WR 4200
# TAJAE SHARPE WR 3900
# COOPER KUPP WR 9500
# AUSTIN HOOPER TE 2800
# DEEBO SAMUEL WR 7400
#
#
# Lineup 98:
#
# LAMAR JACKSON QB 7800
# JAMES ROBINSON RB 6200
# D'ERNEST JOHNSON RB 4700
# MARQUEZ VALDESSCANTLING WR 3500
# TIM PATRICK WR 4900
# DAVANTE ADAMS WR 7900
# JUWAN JOHNSON TE 2500
# COOPER KUPP WR 9500
#
#
# Lineup 99:
#
# MATT RYAN QB 6000
# JAVONTE WILLIAMS RB 5000
# ELIJAH MITCHELL RB 5700
# ROBBY ANDERSON WR 4400
# MECOLE HARDMAN WR 3900
# TERRY MCLAURIN WR 7600
# DALLAS GOEDERT TE 4700
# NAJEE HARRIS RB 7900
#
#
# Lineup 100:
#
# CARSON WENTZ QB 5900
# AUSTIN EKELER RB 7600
# LEONARD FOURNETTE RB 6100
# COREY DAVIS WR 4900
# RASHOD BATEMAN WR 4200
# ADAM THIELEN WR 6700
# ADAM TRAUTMAN TE 3000
# DIONTAE JOHNSON WR 6800
#
#
# Lineup 101:
#
# KIRK COUSINS QB 6100
# LEONARD FOURNETTE RB 6100
# GIOVANI BERNARD RB 4300
# KENDRICK BOURNE WR 4600
# AJ BROWN WR 7800
# STEFON DIGGS WR 7500
# RICKY SEALSJONES TE 3700
# KENYAN DRAKE RB 5100
#
#
# Lineup 102:
#
# KIRK COUSINS QB 6100
# LE'VEON BELL RB 4700
# JEREMY MCNICHOLS RB 5500
# HUNTER RENFROW WR 5100
# ADAM THIELEN WR 6700
# TYLER LOCKETT WR 6500
# HARRISON BRYANT TE 2500
# COOPER KUPP WR 9500
#
#
# Lineup 103:
#
# DEREK CARR QB 6000
# ZACK MOSS RB 5100
# D'ERNEST JOHNSON RB 4700
# AJ BROWN WR 7800
# AMONRA ST BROWN WR 3800
# TYREEK HILL WR 7700
# TJ HOCKENSON TE 5500
# KENDRICK BOURNE WR 4600
#
#
# Lineup 104:
#
# TOM BRADY QB 7600
# MELVIN GORDON RB 5300
# DARRELL HENDERSON RB 6400
# TAJAE SHARPE WR 3900
# EMMANUEL SANDERS WR 5700
# MIKE EVANS WR 6900
# JACK DOYLE TE 3100
# JONATHAN TAYLOR RB 8100
#
#
# Lineup 105:
#
# RYAN TANNEHILL QB 6200
# TY JOHNSON RB 4500
# LE'VEON BELL RB 4700
# COOPER KUPP WR 9500
# JAKOBI MEYERS WR 4800
# CEEDEE LAMB WR 7000
# DONALD PARHAM TE 2600
# TYREEK HILL WR 7700
#
#
# Lineup 106:
#
# TEDDY BRIDGEWATER QB 5500
# AUSTIN EKELER RB 7600
# DARRELL HENDERSON RB 6400
# VAN JEFFERSON WR 4100
# MARQUISE BROWN WR 6700
# JARVIS LANDRY WR 5200
# JARED COOK TE 3200
# NAJEE HARRIS RB 7900
#
#
# Lineup 107:
#
# PJ WALKER QB 5000
# JORDAN HOWARD RB 4900
# CHRISTIAN MCCAFFREY RB 8400
# TIM PATRICK WR 4900
# COURTLAND SUTTON WR 5600
# COLE BEASLEY WR 5200
# MO ALIECOX TE 3100
# COOPER KUPP WR 9500
#
#
# Lineup 108:
#
# JALEN HURTS QB 6500
# LE'VEON BELL RB 4700
# DEVIN SINGLETARY RB 4700
# DEEBO SAMUEL WR 7400
# TIM PATRICK WR 4900
# DAVANTE ADAMS WR 7900
# TAYSOM HILL TE 5200
# ELIJAH MITCHELL RB 5700
#
#
# Lineup 109:
#
# JACOBY BRISSETT QB 5100
# JOSH JACOBS RB 6200
# JD MCKISSIC RB 5200
# KALIF RAYMOND WR 4900
# KEENAN ALLEN WR 7000
# MIKE WILLIAMS WR 6600
# TRAVIS KELCE TE 6900
# ZACK MOSS RB 5100
#
#
# Lineup 110:
#
# RUSSELL WILSON QB 6700
# MIKE DAVIS RB 4600
# D'ANDRE SWIFT RB 6800
# MIKE WILLIAMS WR 6600
# CHRISTIAN KIRK WR 5500
# AMARI COOPER WR 6200
# DALTON SCHULTZ TE 5000
# TAYSOM HILL TE 5200
#
#
# Lineup 111:
#
# JUSTIN HERBERT QB 7300
# JD MCKISSIC RB 5200
# JAMES CONNER RB 6300
# MIKE EVANS WR 6900
# SAMMY WATKINS WR 4300
# COURTLAND SUTTON WR 5600
# DAVID NJOKU TE 3200
# DARRELL HENDERSON RB 6400
#
#
# Lineup 112:
#
# JUSTIN HERBERT QB 7300
# JEFF WILSON RB 5000
# JAVONTE WILLIAMS RB 5000
# KEENAN ALLEN WR 7000
# MARQUISE BROWN WR 6700
# COREY DAVIS WR 4900
# KYLE PITTS TE 5800
# BOSTON SCOTT RB 4900
#
#
# Lineup 113:
#
# AARON RODGERS QB 7100
# DARRELL HENDERSON RB 6400
# TONY POLLARD RB 4600
# AJ GREEN WR 4600
# MARVIN JONES WR 5800
# AJ BROWN WR 7800
# GEORGE KITTLE TE 6000
# SAMMY WATKINS WR 4300
#
#
# Lineup 114:
#
# JIMMY GAROPPOLO QB 5500
# AUSTIN EKELER RB 7600
# JAMES ROBINSON RB 6200
# ALLEN LAZARD WR 4400
# JUSTIN JEFFERSON WR 7700
# RANDALL COBB WR 4300
# DAWSON KNOX TE 4500
# DARRELL HENDERSON RB 6400
#
#
# Lineup 115:
#
# CARSON WENTZ QB 5900
# ZACK MOSS RB 5100
# JEREMY MCNICHOLS RB 5500
# TYLER LOCKETT WR 6500
# STEFON DIGGS WR 7500
# CHRISTIAN KIRK WR 5500
# GEORGE KITTLE TE 6000
# JEFF WILSON RB 5000
#
#
# Lineup 116:
#
# TREVOR LAWRENCE QB 5300
# RHAMONDRE STEVENSON RB 4500
# CHRISTIAN MCCAFFREY RB 8400
# DK METCALF WR 6800
# TERRY MCLAURIN WR 7600
# JAMAL AGNEW WR 4500
# AUSTIN HOOPER TE 2800
# ADAM THIELEN WR 6700
#
#
# Lineup 117:
#
# BAKER MAYFIELD QB 5400
# AUSTIN EKELER RB 7600
# D'ANDRE SWIFT RB 6800
# JALEN GUYTON WR 3600
# JERRY JEUDY WR 5300
# TYREEK HILL WR 7700
# ZACH ERTZ TE 4600
# MYLES GASKIN RB 6000
#
#
# Lineup 118:
#
# TOM BRADY QB 7600
# EZEKIEL ELLIOTT RB 7000
# AUSTIN EKELER RB 7600
# JERRY JEUDY WR 5300
# HUNTER RENFROW WR 5100
# RUSSELL GAGE WR 5000
# AUSTIN HOOPER TE 2800
# DONOVAN PEOPLESJONES WR 4800
#
#
# Lineup 119:
#
# RUSSELL WILSON QB 6700
# EZEKIEL ELLIOTT RB 7000
# D'ERNEST JOHNSON RB 4700
# NELSON AGHOLOR WR 4000
# MIKE WILLIAMS WR 6600
# MICHAEL PITTMAN WR 6300
# RICKY SEALSJONES TE 3700
# TERRY MCLAURIN WR 7600
#
#
# Lineup 120:
#
# JIMMY GAROPPOLO QB 5500
# CARLOS HYDE RB 5000
# DARRELL HENDERSON RB 6400
# DIONTAE JOHNSON WR 6800
# HUNTER RENFROW WR 5100
# TERRY MCLAURIN WR 7600
# MO ALIECOX TE 3100
# STEFON DIGGS WR 7500
#
#
# Lineup 121:
#
# BAKER MAYFIELD QB 5400
# JEFF WILSON RB 5000
# TY JOHNSON RB 4500
# COOPER KUPP WR 9500
# CEEDEE LAMB WR 7000
# KEENAN ALLEN WR 7000
# JACK DOYLE TE 3100
# ANTONIO GIBSON RB 5500
#
#
# Lineup 122:
#
# MATTHEW STAFFORD QB 7000
# JEREMY MCNICHOLS RB 5500
# DARRELL HENDERSON RB 6400
# DAVANTE ADAMS WR 7900
# JALEN GUYTON WR 3600
# MECOLE HARDMAN WR 3900
# NOAH FANT TE 4300
# MIKE WILLIAMS WR 6600
#
#
# Lineup 123:
#
# CASE KEENUM QB 4900
# CORDARRELLE PATTERSON RB 6600
# D'ANDRE SWIFT RB 6800
# DONOVAN PEOPLESJONES WR 4800
# JUSTIN JEFFERSON WR 7700
# DJ MOORE WR 6300
# DURHAM SMYTHE TE 2500
# CEEDEE LAMB WR 7000
#
#
# Lineup 124:
#
# COOPER RUSH QB 4800
# CHRISTIAN MCCAFFREY RB 8400
# D'ERNEST JOHNSON RB 4700
# MARVIN JONES WR 5800
# AMARI COOPER WR 6200
# DAVANTE ADAMS WR 7900
# RICKY SEALSJONES TE 3700
# ZACK MOSS RB 5100
#
#
# Lineup 125:
#
# MATTHEW STAFFORD QB 7000
# MIKE DAVIS RB 4600
# BOSTON SCOTT RB 4900
# COOPER KUPP WR 9500
# MIKE WILLIAMS WR 6600
# ADAM HUMPHRIES WR 3500
# HARRISON BRYANT TE 2500
# CHRISTIAN MCCAFFREY RB 8400
#
#
# Lineup 126:
#
# BAKER MAYFIELD QB 5400
# JAMES CONNER RB 6300
# MICHAEL CARTER RB 5600
# KENDRICK BOURNE WR 4600
# DONOVAN PEOPLESJONES WR 4800
# STEFON DIGGS WR 7500
# MO ALIECOX TE 3100
# DAVANTE ADAMS WR 7900
#
#
# Lineup 127:
#
# BAKER MAYFIELD QB 5400
# ZACK MOSS RB 5100
# JAMES ROBINSON RB 6200
# DIONTAE JOHNSON WR 6800
# MARQUISE BROWN WR 6700
# JAMISON CROWDER WR 4800
# TRAVIS KELCE TE 6900
# DALLAS GOEDERT TE 4700
#
#
# Lineup 128:
#
# TEDDY BRIDGEWATER QB 5500
# BOSTON SCOTT RB 4900
# EZEKIEL ELLIOTT RB 7000
# CEEDEE LAMB WR 7000
# TERRY MCLAURIN WR 7600
# DEVONTA SMITH WR 5900
# TYLER HIGBEE TE 4000
# BRANDON AIYUK WR 4700
#
#
# Lineup 129:
#
# BAKER MAYFIELD QB 5400
# MELVIN GORDON RB 5300
# JOSH JACOBS RB 6200
# SAMMY WATKINS WR 4300
# AMARI COOPER WR 6200
# JAKOBI MEYERS WR 4800
# TRAVIS KELCE TE 6900
# LEONARD FOURNETTE RB 6100
#
#
# Lineup 130:
#
# MATTHEW STAFFORD QB 7000
# RHAMONDRE STEVENSON RB 4500
# NAJEE HARRIS RB 7900
# JUSTIN JEFFERSON WR 7700
# COURTLAND SUTTON WR 5600
# RASHOD BATEMAN WR 4200
# TOMMY TREMBLE TE 2500
# MARVIN JONES WR 5800
#
#
# Lineup 131:
#
# PATRICK MAHOMES QB 7200
# TREY SERMON RB 4300
# AJ DILLON RB 4800
# DIONTAE JOHNSON WR 6800
# DJ MOORE WR 6300
# MARQUISE BROWN WR 6700
# HAYDEN HURST TE 2800
# TYREEK HILL WR 7700
#
#
# Lineup 132:
#
# RYAN TANNEHILL QB 6200
# TREY SERMON RB 4300
# AARON JONES RB 6900
# OLAMIDE ZACCHEAUS WR 4400
# DEONTE HARRIS WR 4000
# COOPER KUPP WR 9500
# RICKY SEALSJONES TE 3700
# JOSH JACOBS RB 6200
#
#
# Lineup 133:
#
# JUSTIN HERBERT QB 7300
# EZEKIEL ELLIOTT RB 7000
# AARON JONES RB 6900
# JALEN GUYTON WR 3600
# MICHAEL PITTMAN WR 6300
# VAN JEFFERSON WR 4100
# TRAVIS KELCE TE 6900
# ADRIAN PETERSON RB 4900
#
#
# Lineup 134:
#
# CARSON WENTZ QB 5900
# JEFF WILSON RB 5000
# CHRISTIAN MCCAFFREY RB 8400
# TERRY MCLAURIN WR 7600
# DEVONTA SMITH WR 5900
# MICHAEL PITTMAN WR 6300
# JARED COOK TE 3200
# KENNY GAINWELL RB 4700
# Lineup 135:
#
# LAMAR JACKSON QB 7800
# RHAMONDRE STEVENSON RB 4500
# D'ERNEST JOHNSON RB 4700
# RUSSELL GAGE WR 5000
# CHRIS GODWIN WR 7100
# JALEN REAGOR WR 3500
# TRAVIS KELCE TE 6900
# MARK ANDREWS TE 5700
#
#
# Lineup 136:
#
# COLT MCCOY QB 5000
# AARON JONES RB 6900
# JONATHAN TAYLOR RB 8100
# MICHAEL PITTMAN WR 6300
# DIONTAE JOHNSON WR 6800
# RUSSELL GAGE WR 5000
# GERALD EVERETT TE 2600
# JAMAL AGNEW WR 4500
#
#
# Lineup 137:
#
# JUSTIN HERBERT QB 7300
# CHRISTIAN MCCAFFREY RB 8400
# TY JOHNSON RB 4500
# RUSSELL GAGE WR 5000
# MIKE EVANS WR 6900
# MECOLE HARDMAN WR 3900
# PAT FREIERMUTH TE 3900
# CHRIS GODWIN WR 7100
#
#
# Lineup 138:
#
# DAK PRESCOTT QB 6900
# JONATHAN TAYLOR RB 8100
# AJ DILLON RB 4800
# AMARI COOPER WR 6200
# TY HILTON WR 4700
# ADAM THIELEN WR 6700
# DAVID NJOKU TE 3200
# ZACH ERTZ TE 4600
#
#
# Lineup 139:
#
# AARON RODGERS QB 7100
# DARREL WILLIAMS RB 5400
# NYHEIM HINES RB 5000
# AJ BROWN WR 7800
# MICHAEL GALLUP WR 4000
# DJ MOORE WR 6300
# TRAVIS KELCE TE 6900
# VAN JEFFERSON WR 4100
#
#
# Lineup 140:
#
# DEREK CARR QB 6000
# JEFF WILSON RB 5000
# D'ANDRE SWIFT RB 6800
# AMARI COOPER WR 6200
# RUSSELL GAGE WR 5000
# TERRY MCLAURIN WR 7600
# HARRISON BRYANT TE 2500
# NAJEE HARRIS RB 7900
#
#
# Lineup 141:
#
# DEREK CARR QB 6000
# EZEKIEL ELLIOTT RB 7000
# JONATHAN TAYLOR RB 8100
# LAVISKA SHENAULT WR 4600
# NELSON AGHOLOR WR 4000
# TYREEK HILL WR 7700
# MIKE GESICKI TE 4900
# LE'VEON BELL RB 4700
#
#
# Lineup 142:
#
# AARON RODGERS QB 7100
# AUSTIN EKELER RB 7600
# JONATHAN TAYLOR RB 8100
# AMONRA ST BROWN WR 3800
# KENDRICK BOURNE WR 4600
# MICHAEL PITTMAN WR 6300
# TOMMY TREMBLE TE 2500
# KEENAN ALLEN WR 7000
#
#
# Lineup 143:
#
# TEDDY BRIDGEWATER QB 5500
# ELIJAH MITCHELL RB 5700
# MYLES GASKIN RB 6000
# DEVONTA SMITH WR 5900
# STEFON DIGGS WR 7500
# KEENAN ALLEN WR 7000
# DALLAS GOEDERT TE 4700
# ELIJAH MOORE WR 4700
#
#
# Lineup 144:
#
# COOPER RUSH QB 4800
# NAJEE HARRIS RB 7900
# AARON JONES RB 6900
# AJ BROWN WR 7800
# MARQUEZ CALLAWAY WR 5100
# ADAM THIELEN WR 6700
# JARED COOK TE 3200
# TONY POLLARD RB 4600
#
#
# Lineup 145:
#
# JUSTIN HERBERT QB 7300
# D'ERNEST JOHNSON RB 4700
# DARREL WILLIAMS RB 5400
# AMARI COOPER WR 6200
# DK METCALF WR 6800
# CEEDEE LAMB WR 7000
# ZACH ERTZ TE 4600
# KENDRICK BOURNE WR 4600
#
#
# Lineup 146:
#
# MAC JONES QB 5300
# ANTONIO GIBSON RB 5500
# ADRIAN PETERSON RB 4900
# CHRIS GODWIN WR 7100
# JERRY JEUDY WR 5300
# COOPER KUPP WR 9500
# NOAH FANT TE 4300
# HUNTER RENFROW WR 5100
#
#
# Lineup 147:
#
# AARON RODGERS QB 7100
# JONATHAN TAYLOR RB 8100
# DALVIN COOK RB 8000
# JAMAL AGNEW WR 4500
# RANDALL COBB WR 4300
# COLE BEASLEY WR 5200
# DALTON SCHULTZ TE 5000
# RONDALE MOORE WR 4400
#
#
# Lineup 148:
#
# JUSTIN HERBERT QB 7300
# DEVONTA FREEMAN RB 5000
# MELVIN GORDON RB 5300
# KENDRICK BOURNE WR 4600
# JALEN GUYTON WR 3600
# AJ BROWN WR 7800
# TRAVIS KELCE TE 6900
# LEONARD FOURNETTE RB 6100
#
#
# Lineup 149:
#
# DEREK CARR QB 6000
# NAJEE HARRIS RB 7900
# JEREMY MCNICHOLS RB 5500
# MICHAEL PITTMAN WR 6300
# JALEN REAGOR WR 3500
# DIONTAE JOHNSON WR 6800
# TJ HOCKENSON TE 5500
# KENYAN DRAKE RB 5100
#
#
# Lineup 150:
#
# TEDDY BRIDGEWATER QB 5500
# DARRELL HENDERSON RB 6400
# DEVONTA FREEMAN RB 5000
# DAVANTE ADAMS WR 7900
# KENDRICK BOURNE WR 4600
# MICHAEL PITTMAN WR 6300
# DAWSON KNOX TE 4500
# RUSSELL GAGE WR 5000
#
#
# Lineup 151:
#
# CASE KEENUM QB 4900
# JEFF WILSON RB 5000
# AUSTIN EKELER RB 7600
# JUSTIN JEFFERSON WR 7700
# MIKE EVANS WR 6900
# DEVONTA SMITH WR 5900
# HUNTER HENRY TE 4100
# ALEXANDER MATTISON RB 4500
#
#
# Lineup 152:
#
# MATTHEW STAFFORD QB 7000
# BOSTON SCOTT RB 4900
# NAJEE HARRIS RB 7900
# JERRY JEUDY WR 5300
# MARQUEZ CALLAWAY WR 5100
# CHRIS GODWIN WR 7100
# ALBERT OKWUEGBUNAM TE 3300
# TONY POLLARD RB 4600
#
#
# Lineup 153:
#
# TOM BRADY QB 7600
# MELVIN GORDON RB 5300
# JD MCKISSIC RB 5200
# DEEBO SAMUEL WR 7400
# CHRIS GODWIN WR 7100
# JAMAL AGNEW WR 4500
# MO ALIECOX TE 3100
# DARRELL HENDERSON RB 6400
#
#
# Lineup 154:
#
# DAK PRESCOTT QB 6900
# AARON JONES RB 6900
# BOSTON SCOTT RB 4900
# DIONTAE JOHNSON WR 6800
# TIM PATRICK WR 4900
# TRE'QUAN SMITH WR 4300
# TYLER HIGBEE TE 4000
# DAVANTE ADAMS WR 7900
#
#
# Lineup 155:
#
# TAYLOR HEINICKE QB 5400
# AARON JONES RB 6900
# ZACK MOSS RB 5100
# NELSON AGHOLOR WR 4000
# JUSTIN JEFFERSON WR 7700
# BRANDON AIYUK WR 4700
# RICKY SEALSJONES TE 3700
# TYREEK HILL WR 7700
#
#
# Lineup 156:
#
# PATRICK MAHOMES QB 7200
# AARON JONES RB 6900
# DALVIN COOK RB 8000
# NELSON AGHOLOR WR 4000
# ADAM THIELEN WR 6700
# JERRY JEUDY WR 5300
# PAT FREIERMUTH TE 3900
# DALTON SCHULTZ TE 5000
#
#
# Lineup 157:
#
# TOM BRADY QB 7600
# ELIJAH MITCHELL RB 5700
# DEVONTA FREEMAN RB 5000
# ADAM HUMPHRIES WR 3500
# DK METCALF WR 6800
# MIKE WILLIAMS WR 6600
# DALTON SCHULTZ TE 5000
# D'ANDRE SWIFT RB 6800
#
#
# Lineup 158:
#
# CARSON WENTZ QB 5900
# AARON JONES RB 6900
# JOSH JACOBS RB 6200
# ZACH PASCAL WR 4500
# TYREEK HILL WR 7700
# ELIJAH MOORE WR 4700
# DURHAM SMYTHE TE 2500
# DIONTAE JOHNSON WR 6800
#
#
# Lineup 159:
#
# MATTHEW STAFFORD QB 7000
# AJ DILLON RB 4800
# LEONARD FOURNETTE RB 6100
# MICHAEL GALLUP WR 4000
# JAKOBI MEYERS WR 4800
# JUSTIN JEFFERSON WR 7700
# DARREN WALLER TE 6300
# JAMAL AGNEW WR 4500
#
#
# Lineup 160:
#
# TOM BRADY QB 7600
# JAMES ROBINSON RB 6200
# ENO BENJAMIN RB 4400
# LAVISKA SHENAULT WR 4600
# AJ BROWN WR 7800
# KEENAN ALLEN WR 7000
# MIKE GESICKI TE 4900
# DEEJAY DALLAS RB 4100
#
#
# Lineup 161:
#
# PJ WALKER QB 5000
# BRANDON BOLDEN RB 4400
# JOSH JACOBS RB 6200
# COOPER KUPP WR 9500
# BRANDON AIYUK WR 4700
# DJ MOORE WR 6300
# TJ HOCKENSON TE 5500
# DARREL WILLIAMS RB 5400
#
#
# Lineup 162:
#
# MATTHEW STAFFORD QB 7000
# AUSTIN EKELER RB 7600
# CHRISTIAN MCCAFFREY RB 8400
# VAN JEFFERSON WR 4100
# JERRY JEUDY WR 5300
# JALEN REAGOR WR 3500
# ZACH ERTZ TE 4600
# KENNY GAINWELL RB 4700
#
#
# Lineup 163:
#
# LAMAR JACKSON QB 7800
# JEFF WILSON RB 5000
# ZACK MOSS RB 5100
# DEVONTA SMITH WR 5900
# AMARI COOPER WR 6200
# TYREEK HILL WR 7700
# TOMMY TREMBLE TE 2500
# DEVONTA FREEMAN RB 5000
#
#
# Lineup 164:
#
# RYAN TANNEHILL QB 6200
# NAJEE HARRIS RB 7900
# JAMES CONNER RB 6300
# AJ BROWN WR 7800
# MICHAEL GALLUP WR 4000
# BRYAN EDWARDS WR 4200
# KYLE PITTS TE 5800
# JAKOBI MEYERS WR 4800
#
#
# Lineup 165:
#
# RYAN TANNEHILL QB 6200
# LEONARD FOURNETTE RB 6100
# D'ANDRE SWIFT RB 6800
# STEFON DIGGS WR 7500
# NELSON AGHOLOR WR 4000
# KALIF RAYMOND WR 4900
# DAWSON KNOX TE 4500
# JARVIS LANDRY WR 5200
#
#
# Lineup 166:
#
# PATRICK MAHOMES QB 7200
# ENO BENJAMIN RB 4400
# JONATHAN TAYLOR RB 8100
# BRANDON AIYUK WR 4700
# DK METCALF WR 6800
# JAMISON CROWDER WR 4800
# TYLER HIGBEE TE 4000
# JARVIS LANDRY WR 5200
#
#
# Lineup 167:
#
# JIMMY GAROPPOLO QB 5500
# CHRISTIAN MCCAFFREY RB 8400
# JAMES CONNER RB 6300
# ADAM THIELEN WR 6700
# MIKE WILLIAMS WR 6600
# CHRISTIAN KIRK WR 5500
# DONALD PARHAM TE 2600
# CARLOS HYDE RB 5000
#
#
# Lineup 168:
#
# TUA TAGOVAILOA QB 5600
# JALEN RICHARD RB 4200
# LEONARD FOURNETTE RB 6100
# JUSTIN JEFFERSON WR 7700
# AJ BROWN WR 7800
# JAKOBI MEYERS WR 4800
# KYLE PITTS TE 5800
# KENDRICK BOURNE WR 4600
#
#
# Lineup 169:
#
# KIRK COUSINS QB 6100
# BOSTON SCOTT RB 4900
# MYLES GASKIN RB 6000
# DAVANTE ADAMS WR 7900
# ADAM THIELEN WR 6700
# DONOVAN PEOPLESJONES WR 4800
# HUNTER HENRY TE 4100
# LEONARD FOURNETTE RB 6100
#
#
# Lineup 170:
#
# TEDDY BRIDGEWATER QB 5500
# LEONARD FOURNETTE RB 6100
# JORDAN HOWARD RB 4900
# COOPER KUPP WR 9500
# TRE'QUAN SMITH WR 4300
# JUSTIN JEFFERSON WR 7700
# GERALD EVERETT TE 2600
# GEORGE KITTLE TE 6000
#
#
# Lineup 171:
#
# TUA TAGOVAILOA QB 5600
# AJ DILLON RB 4800
# JAMES ROBINSON RB 6200
# DIONTAE JOHNSON WR 6800
# BRANDON AIYUK WR 4700
# JAKOBI MEYERS WR 4800
# GEORGE KITTLE TE 6000
# DARREN WALLER TE 6300
#
#
# Lineup 172:
#
# LAMAR JACKSON QB 7800
# ELIJAH MITCHELL RB 5700
# MYLES GASKIN RB 6000
# AMARI COOPER WR 6200
# RANDALL COBB WR 4300
# SAMMY WATKINS WR 4300
# TRAVIS KELCE TE 6900
# MARVIN JONES WR 5800
#
#
# Lineup 173:
#
# BAKER MAYFIELD QB 5400
# D'ANDRE SWIFT RB 6800
# DEVIN SINGLETARY RB 4700
# JUSTIN JEFFERSON WR 7700
# LAVISKA SHENAULT WR 4600
# CEEDEE LAMB WR 7000
# GEORGE KITTLE TE 6000
# AJ DILLON RB 4800
#
#
# Lineup 174:
#
# MIKE WHITE QB 5100
# ALEX COLLINS RB 5200
# BRANDON BOLDEN RB 4400
# JUSTIN JEFFERSON WR 7700
# JARVIS LANDRY WR 5200
# MARQUISE BROWN WR 6700
# ZACH ERTZ TE 4600
# DJ MOORE WR 6300
#
#
# Lineup 175:
#
# COOPER RUSH QB 4800
# D'ANDRE SWIFT RB 6800
# AJ DILLON RB 4800
# KALIF RAYMOND WR 4900
# CEEDEE LAMB WR 7000
# DJ MOORE WR 6300
# KYLE PITTS TE 5800
# DONOVAN PEOPLESJONES WR 4800
#
#
# Lineup 176:
#
# MIKE WHITE QB 5100
# DALVIN COOK RB 8000
# AUSTIN EKELER RB 7600
# AJ GREEN WR 4600
# DIONTAE JOHNSON WR 6800
# MICHAEL PITTMAN WR 6300
# HUNTER HENRY TE 4100
# TY JOHNSON RB 4500
#
#
# Lineup 177:
#
# JUSTIN HERBERT QB 7300
# JEFF WILSON RB 5000
# DARRELL HENDERSON RB 6400
# ZACH PASCAL WR 4500
# TYLER LOCKETT WR 6500
# EMMANUEL SANDERS WR 5700
# TAYSOM HILL TE 5200
# MYLES GASKIN RB 6000
#
#
# Lineup 178:
#
# COLT MCCOY QB 5000
# CORDARRELLE PATTERSON RB 6600
# GIOVANI BERNARD RB 4300
# DONOVAN PEOPLESJONES WR 4800
# STEFON DIGGS WR 7500
# JAMAL AGNEW WR 4500
# MARK ANDREWS TE 5700
# DIONTAE JOHNSON WR 6800
# Lineup 179:
#
# AARON RODGERS QB 7100
# CHRISTIAN MCCAFFREY RB 8400
# ALEXANDER MATTISON RB 4500
# TYLER LOCKETT WR 6500
# VAN JEFFERSON WR 4100
# TYREEK HILL WR 7700
# TYLER HIGBEE TE 4000
# LE'VEON BELL RB 4700
#
#
# Lineup 180:
#
# DAK PRESCOTT QB 6900
# D'ANDRE SWIFT RB 6800
# NAJEE HARRIS RB 7900
# COOPER KUPP WR 9500
# MARQUEZ VALDESSCANTLING WR 3500
# CEDRICK WILSON WR 3500
# JARED COOK TE 3200
# MELVIN GORDON RB 5300
#
#
# Lineup 181:
#
# DEREK CARR QB 6000
# NYHEIM HINES RB 5000
# DARRELL HENDERSON RB 6400
# JAMAL AGNEW WR 4500
# CEEDEE LAMB WR 7000
# COURTLAND SUTTON WR 5600
# GEORGE KITTLE TE 6000
# D'ERNEST JOHNSON RB 4700
#
#
# Lineup 182:
#
# COOPER RUSH QB 4800
# GIOVANI BERNARD RB 4300
# NAJEE HARRIS RB 7900
# DK METCALF WR 6800
# RANDALL COBB WR 4300
# TRE'QUAN SMITH WR 4300
# DALLAS GOEDERT TE 4700
# COOPER KUPP WR 9500
#
#
# Lineup 183:
#
# DAK PRESCOTT QB 6900
# JOSH JACOBS RB 6200
# DALVIN COOK RB 8000
# MIKE WILLIAMS WR 6600
# CEDRICK WILSON WR 3500
# HUNTER RENFROW WR 5100
# DONALD PARHAM TE 2600
# JONATHAN TAYLOR RB 8100
#
#
# Lineup 184:
#
# BAKER MAYFIELD QB 5400
# LEONARD FOURNETTE RB 6100
# NYHEIM HINES RB 5000
# KENDRICK BOURNE WR 4600
# MICHAEL PITTMAN WR 6300
# MARQUISE BROWN WR 6700
# TJ HOCKENSON TE 5500
# DEEBO SAMUEL WR 7400
#
#
# Lineup 185:
#
# RUSSELL WILSON QB 6700
# NAJEE HARRIS RB 7900
# BOSTON SCOTT RB 4900
# MARQUISE BROWN WR 6700
# JUSTIN JEFFERSON WR 7700
# MECOLE HARDMAN WR 3900
# IAN THOMAS TE 2500
# COREY DAVIS WR 4900
#
#
# Lineup 186:
#
# RUSSELL WILSON QB 6700
# MYLES GASKIN RB 6000
# LE'VEON BELL RB 4700
# MARQUISE BROWN WR 6700
# TYREEK HILL WR 7700
# JARVIS LANDRY WR 5200
# DAVID NJOKU TE 3200
# DK METCALF WR 6800
#
#
# Lineup 187:
#
# TOM BRADY QB 7600
# LE'VEON BELL RB 4700
# DEVIN SINGLETARY RB 4700
# TAJAE SHARPE WR 3900
# COOPER KUPP WR 9500
# CEEDEE LAMB WR 7000
# OJ HOWARD TE 2700
# MARQUEZ CALLAWAY WR 5100
#
#
# Lineup 188:
#
# TREVOR LAWRENCE QB 5300
# CHRISTIAN MCCAFFREY RB 8400
# JEFF WILSON RB 5000
# JAMES WASHINGTON WR 3500
# RUSSELL GAGE WR 5000
# MIKE EVANS WR 6900
# RICKY SEALSJONES TE 3700
# DEEBO SAMUEL WR 7400
#
#
# Lineup 189:
#
# DAK PRESCOTT QB 6900
# DARREL WILLIAMS RB 5400
# CORDARRELLE PATTERSON RB 6600
# MARQUEZ VALDESSCANTLING WR 3500
# TERRY MCLAURIN WR 7600
# BRANDON AIYUK WR 4700
# DALTON SCHULTZ TE 5000
# AARON JONES RB 6900
#
#
# Lineup 190:
#
# MATTHEW STAFFORD QB 7000
# D'ERNEST JOHNSON RB 4700
# JAMES ROBINSON RB 6200
# COREY DAVIS WR 4900
# JAYLEN WADDLE WR 5500
# COOPER KUPP WR 9500
# ADAM TRAUTMAN TE 3000
# AMARI COOPER WR 6200
#
#
# Lineup 191:
#
# BAKER MAYFIELD QB 5400
# ANTONIO GIBSON RB 5500
# MICHAEL CARTER RB 5600
# TERRY MCLAURIN WR 7600
# JUSTIN JEFFERSON WR 7700
# SAMMY WATKINS WR 4300
# TYLER CONKLIN TE 3400
# MARK ANDREWS TE 5700
#
#
# Lineup 192:
#
# BAKER MAYFIELD QB 5400
# MYLES GASKIN RB 6000
# RHAMONDRE STEVENSON RB 4500
# ADAM HUMPHRIES WR 3500
# KEENAN ALLEN WR 7000
# JUSTIN JEFFERSON WR 7700
# HUNTER HENRY TE 4100
# CHRISTIAN MCCAFFREY RB 8400
#
#
# Lineup 193:
#
# AARON RODGERS QB 7100
# AUSTIN EKELER RB 7600
# ADRIAN PETERSON RB 4900
# ADAM THIELEN WR 6700
# CHRISTIAN KIRK WR 5500
# JARVIS LANDRY WR 5200
# TAYSOM HILL TE 5200
# DONOVAN PEOPLESJONES WR 4800
#
#
# Lineup 194:
#
# MIKE WHITE QB 5100
# ELIJAH MITCHELL RB 5700
# MELVIN GORDON RB 5300
# MIKE WILLIAMS WR 6600
# DK METCALF WR 6800
# MICHAEL PITTMAN WR 6300
# TOMMY TREMBLE TE 2500
# MIKE EVANS WR 6900
#
#
# Lineup 195:
#
# TEDDY BRIDGEWATER QB 5500
# MICHAEL CARTER RB 5600
# DALVIN COOK RB 8000
# AMONRA ST BROWN WR 3800
# TRE'QUAN SMITH WR 4300
# DJ MOORE WR 6300
# MARK ANDREWS TE 5700
# GEORGE KITTLE TE 6000
#
#
# Lineup 196:
#
# PJ WALKER QB 5000
# CHRISTIAN MCCAFFREY RB 8400
# ELIJAH MITCHELL RB 5700
# SAMMY WATKINS WR 4300
# ADAM THIELEN WR 6700
# QUEZ WATKINS WR 3600
# KYLE PITTS TE 5800
# MARK ANDREWS TE 5700
#
#
# Lineup 197:
#
# TOM BRADY QB 7600
# CHUBA HUBBARD RB 5400
# JAMES CONNER RB 6300
# DONOVAN PEOPLESJONES WR 4800
# CEEDEE LAMB WR 7000
# STEFON DIGGS WR 7500
# MO ALIECOX TE 3100
# JERRY JEUDY WR 5300
#
#
# Lineup 198:
#
# RUSSELL WILSON QB 6700
# ENO BENJAMIN RB 4400
# CHRISTIAN MCCAFFREY RB 8400
# CHRIS GODWIN WR 7100
# RUSSELL GAGE WR 5000
# COREY DAVIS WR 4900
# MIKE GESICKI TE 4900
# JARVIS LANDRY WR 5200
#
#
# Lineup 199:
#
# COLT MCCOY QB 5000
# D'ANDRE SWIFT RB 6800
# NAJEE HARRIS RB 7900
# TAJAE SHARPE WR 3900
# JALEN REAGOR WR 3500
# TYREEK HILL WR 7700
# DALTON SCHULTZ TE 5000
# DIONTAE JOHNSON WR 6800
#
#
# Lineup 200:
#
# DEREK CARR QB 6000
# ZACK MOSS RB 5100
# LEONARD FOURNETTE RB 6100
# RONDALE MOORE WR 4400
# MARQUISE BROWN WR 6700
# MICHAEL PITTMAN WR 6300
# TJ HOCKENSON TE 5500
# KENYAN DRAKE RB 5100
#
#
# Lineup 201:
#
# CARSON WENTZ QB 5900
# ZACK MOSS RB 5100
# NYHEIM HINES RB 5000
# DEEBO SAMUEL WR 7400
# DAVANTE ADAMS WR 7900
# KALIF RAYMOND WR 4900
# TOMMY SWEENEY TE 2600
# DARRELL HENDERSON RB 6400
#
#
# Lineup 202:
#
# RYAN TANNEHILL QB 6200
# JAMES ROBINSON RB 6200
# ENO BENJAMIN RB 4400
# STEFON DIGGS WR 7500
# COREY DAVIS WR 4900
# MIKE EVANS WR 6900
# DALTON SCHULTZ TE 5000
# JAYLEN WADDLE WR 5500
#
#
# Lineup 203:
#
# LAMAR JACKSON QB 7800
# MICHAEL CARTER RB 5600
# DARRELL HENDERSON RB 6400
# JAKOBI MEYERS WR 4800
# STEFON DIGGS WR 7500
# DIONTAE JOHNSON WR 6800
# MO ALIECOX TE 3100
# DALTON SCHULTZ TE 5000
#
#
# Lineup 204:
#
# TAYLOR HEINICKE QB 5400
# CORDARRELLE PATTERSON RB 6600
# JEREMY MCNICHOLS RB 5500
# MICHAEL PITTMAN WR 6300
# JAYLEN WADDLE WR 5500
# AJ BROWN WR 7800
# MO ALIECOX TE 3100
# DIONTAE JOHNSON WR 6800
#
#
# Lineup 205:
#
# MIKE WHITE QB 5100
# DALVIN COOK RB 8000
# GIOVANI BERNARD RB 4300
# RUSSELL GAGE WR 5000
# KENDRICK BOURNE WR 4600
# COOPER KUPP WR 9500
# MARK ANDREWS TE 5700
# JAMISON CROWDER WR 4800
#
#
# Lineup 206:
#
# CASE KEENUM QB 4900
# JEFF WILSON RB 5000
# NAJEE HARRIS RB 7900
# TYLER LOCKETT WR 6500
# CHRIS GODWIN WR 7100
# JAYLEN WADDLE WR 5500
# JACK DOYLE TE 3100
# ALEX COLLINS RB 5200
#
#
# Lineup 207:
#
# DAK PRESCOTT QB 6900
# JONATHAN TAYLOR RB 8100
# DEVIN SINGLETARY RB 4700
# EMMANUEL SANDERS WR 5700
# RASHOD BATEMAN WR 4200
# COOPER KUPP WR 9500
# JARED COOK TE 3200
# GIOVANI BERNARD RB 4300
#
#
# Lineup 208:
#
# MATT RYAN QB 6000
# DARRELL HENDERSON RB 6400
# AUSTIN EKELER RB 7600
# JALEN GUYTON WR 3600
# DEONTE HARRIS WR 4000
# TERRY MCLAURIN WR 7600
# TJ HOCKENSON TE 5500
# DAWSON KNOX TE 4500
#
#
# Lineup 209:
#
# JIMMY GAROPPOLO QB 5500
# DEEJAY DALLAS RB 4100
# KENYAN DRAKE RB 5100
# TRE'QUAN SMITH WR 4300
# TERRY MCLAURIN WR 7600
# MIKE WILLIAMS WR 6600
# TAYSOM HILL TE 5200
# D'ANDRE SWIFT RB 6800
#
#
# Lineup 210:
#
# TOM BRADY QB 7600
# D'ANDRE SWIFT RB 6800
# MIKE DAVIS RB 4600
# MARQUEZ CALLAWAY WR 5100
# AJ BROWN WR 7800
# KENDRICK BOURNE WR 4600
# ADAM TRAUTMAN TE 3000
# EMMANUEL SANDERS WR 5700
#
#
# Lineup 211:
#
# COOPER RUSH QB 4800
# EZEKIEL ELLIOTT RB 7000
# CARLOS HYDE RB 5000
# COLE BEASLEY WR 5200
# MIKE WILLIAMS WR 6600
# AJ BROWN WR 7800
# IAN THOMAS TE 2500
# JAMES CONNER RB 6300
#
#
# Lineup 212:
#
# PATRICK MAHOMES QB 7200
# TY JOHNSON RB 4500
# CORDARRELLE PATTERSON RB 6600
# DEEBO SAMUEL WR 7400
# MECOLE HARDMAN WR 3900
# RUSSELL GAGE WR 5000
# ADAM TRAUTMAN TE 3000
# AUSTIN EKELER RB 7600
#
#
# Lineup 213:
#
# TREVOR SIEMIAN QB 5200
# MICHAEL CARTER RB 5600
# DALVIN COOK RB 8000
# JARVIS LANDRY WR 5200
# VAN JEFFERSON WR 4100
# KENDRICK BOURNE WR 4600
# MIKE GESICKI TE 4900
# AUSTIN EKELER RB 7600
#
#
# Lineup 214:
#
# KIRK COUSINS QB 6100
# DALVIN COOK RB 8000
# NAJEE HARRIS RB 7900
# JAMISON CROWDER WR 4800
# TRE'QUAN SMITH WR 4300
# CHRIS GODWIN WR 7100
# DAVID NJOKU TE 3200
# MICHAEL CARTER RB 5600
#
#
# Lineup 215:
#
# COOPER RUSH QB 4800
# LEONARD FOURNETTE RB 6100
# MYLES GASKIN RB 6000
# DEEBO SAMUEL WR 7400
# DONOVAN PEOPLESJONES WR 4800
# KENDRICK BOURNE WR 4600
# DARREN WALLER TE 6300
# JD MCKISSIC RB 5200
#
#
# Lineup 216:
#
# PATRICK MAHOMES QB 7200
# MARK INGRAM RB 4500
# MYLES GASKIN RB 6000
# COREY DAVIS WR 4900
# AJ BROWN WR 7800
# COURTLAND SUTTON WR 5600
# JACK DOYLE TE 3100
# DAVANTE ADAMS WR 7900
#
#
# Lineup 217:
#
# CARSON WENTZ QB 5900
# DEVONTA FREEMAN RB 5000
# EZEKIEL ELLIOTT RB 7000
# RANDALL COBB WR 4300
# COOPER KUPP WR 9500
# ADAM THIELEN WR 6700
# RICKY SEALSJONES TE 3700
# TIM PATRICK WR 4900
#
#
# Lineup 218:
#
# DEREK CARR QB 6000
# MELVIN GORDON RB 5300
# LE'VEON BELL RB 4700
# COOPER KUPP WR 9500
# HUNTER RENFROW WR 5100
# JAMISON CROWDER WR 4800
# DALTON SCHULTZ TE 5000
# CORDARRELLE PATTERSON RB 6600
#
#
# Lineup 219:
#
# JACOBY BRISSETT QB 5100
# DARREL WILLIAMS RB 5400
# TREY SERMON RB 4300
# KEENAN ALLEN WR 7000
# STEFON DIGGS WR 7500
# TYREEK HILL WR 7700
# KYLE PITTS TE 5800
# RASHOD BATEMAN WR 4200
#
#
# Lineup 220:
#
# LAMAR JACKSON QB 7800
# JORDAN HOWARD RB 4900
# JAVONTE WILLIAMS RB 5000
# HUNTER RENFROW WR 5100
# JALEN GUYTON WR 3600
# TYREEK HILL WR 7700
# MIKE GESICKI TE 4900
# JOSH JACOBS RB 6200
#
#
# Lineup 221:
#
# TAYLOR HEINICKE QB 5400
# KENNY GAINWELL RB 4700
# NYHEIM HINES RB 5000
# MARQUEZ VALDESSCANTLING WR 3500
# MIKE WILLIAMS WR 6600
# TYLER LOCKETT WR 6500
# TRAVIS KELCE TE 6900
# DALVIN COOK RB 8000
#
#
# Lineup 222:
#
# TOM BRADY QB 7600
# NYHEIM HINES RB 5000
# NAJEE HARRIS RB 7900
# DEONTE HARRIS WR 4000
# TYREEK HILL WR 7700
# TYLER LOCKETT WR 6500
# ALBERT OKWUEGBUNAM TE 3300
# ZACH ERTZ TE 4600
# Lineup 223:
#
# TOM BRADY QB 7600
# MELVIN GORDON RB 5300
# JEFF WILSON RB 5000
# JAMISON CROWDER WR 4800
# DIONTAE JOHNSON WR 6800
# MARVIN JONES WR 5800
# AUSTIN HOOPER TE 2800
# CHRIS GODWIN WR 7100
#
#
# Lineup 224:
#
# RUSSELL WILSON QB 6700
# LEONARD FOURNETTE RB 6100
# MICHAEL CARTER RB 5600
# BRYAN EDWARDS WR 4200
# OLAMIDE ZACCHEAUS WR 4400
# MICHAEL PITTMAN WR 6300
# TRAVIS KELCE TE 6900
# NYHEIM HINES RB 5000
#
#
# Lineup 225:
#
# JALEN HURTS QB 6500
# JEFF WILSON RB 5000
# NAJEE HARRIS RB 7900
# KENDRICK BOURNE WR 4600
# MARVIN JONES WR 5800
# TYREEK HILL WR 7700
# JUWAN JOHNSON TE 2500
# CEEDEE LAMB WR 7000
#
#
# Lineup 226:
#
# MATTHEW STAFFORD QB 7000
# NAJEE HARRIS RB 7900
# MICHAEL CARTER RB 5600
# BRANDON AIYUK WR 4700
# AJ BROWN WR 7800
# JAKOBI MEYERS WR 4800
# PAT FREIERMUTH TE 3900
# MELVIN GORDON RB 5300
#
#
# Lineup 227:
#
# MATT RYAN QB 6000
# SONY MICHEL RB 4300
# JAMES ROBINSON RB 6200
# COURTLAND SUTTON WR 5600
# ALLEN LAZARD WR 4400
# TERRY MCLAURIN WR 7600
# MIKE GESICKI TE 4900
# JOSH JACOBS RB 6200
#
#
# Lineup 228:
#
# TAYLOR HEINICKE QB 5400
# RHAMONDRE STEVENSON RB 4500
# JEREMY MCNICHOLS RB 5500
# JAYLEN WADDLE WR 5500
# STEFON DIGGS WR 7500
# DEEBO SAMUEL WR 7400
# MARK ANDREWS TE 5700
# TJ HOCKENSON TE 5500
#
#
# Lineup 229:
#
# PJ WALKER QB 5000
# MICHAEL CARTER RB 5600
# DALVIN COOK RB 8000
# ROBBY ANDERSON WR 4400
# EMMANUEL SANDERS WR 5700
# AJ BROWN WR 7800
# RICKY SEALSJONES TE 3700
# DK METCALF WR 6800
#
#
# Lineup 230:
#
# JUSTIN HERBERT QB 7300
# EZEKIEL ELLIOTT RB 7000
# LE'VEON BELL RB 4700
# NELSON AGHOLOR WR 4000
# TY HILTON WR 4700
# AJ BROWN WR 7800
# TRAVIS KELCE TE 6900
# TONY POLLARD RB 4600
#
#
# Lineup 231:
#
# TUA TAGOVAILOA QB 5600
# TRAVIS HOMER RB 4500
# ALEX COLLINS RB 5200
# RANDALL COBB WR 4300
# DAVANTE ADAMS WR 7900
# AJ BROWN WR 7800
# DARREN WALLER TE 6300
# CHUBA HUBBARD RB 5400
#
#
# Lineup 232:
#
# TOM BRADY QB 7600
# D'ERNEST JOHNSON RB 4700
# D'ANDRE SWIFT RB 6800
# DIONTAE JOHNSON WR 6800
# CEEDEE LAMB WR 7000
# KALIF RAYMOND WR 4900
# TOMMY TREMBLE TE 2500
# DJ MOORE WR 6300
#
#
# Lineup 233:
#
# MAC JONES QB 5300
# JONATHAN TAYLOR RB 8100
# DALVIN COOK RB 8000
# MARQUEZ CALLAWAY WR 5100
# MARQUISE BROWN WR 6700
# OLAMIDE ZACCHEAUS WR 4400
# MIKE GESICKI TE 4900
# HUNTER HENRY TE 4100
#
#
# Lineup 234:
#
# TOM BRADY QB 7600
# ZACK MOSS RB 5100
# DALVIN COOK RB 8000
# NELSON AGHOLOR WR 4000
# VAN JEFFERSON WR 4100
# TY HILTON WR 4700
# DALLAS GOEDERT TE 4700
# CEEDEE LAMB WR 7000
#
#
# Lineup 235:
#
# JACOBY BRISSETT QB 5100
# JAMES CONNER RB 6300
# ZACK MOSS RB 5100
# JAKOBI MEYERS WR 4800
# ELIJAH MOORE WR 4700
# DEEBO SAMUEL WR 7400
# TJ HOCKENSON TE 5500
# TYREEK HILL WR 7700
#
#
# Lineup 236:
#
# RYAN TANNEHILL QB 6200
# AARON JONES RB 6900
# GIOVANI BERNARD RB 4300
# TYREEK HILL WR 7700
# MARQUEZ CALLAWAY WR 5100
# CHRISTIAN KIRK WR 5500
# ZACH ERTZ TE 4600
# JORDAN HOWARD RB 4900
#
#
# Lineup 237:
#
# AARON RODGERS QB 7100
# ANTONIO GIBSON RB 5500
# SONY MICHEL RB 4300
# BRANDON AIYUK WR 4700
# MARQUISE BROWN WR 6700
# DIONTAE JOHNSON WR 6800
# DAN ARNOLD TE 3500
# CORDARRELLE PATTERSON RB 6600
#
#
# Lineup 238:
#
# RUSSELL WILSON QB 6700
# EZEKIEL ELLIOTT RB 7000
# AARON JONES RB 6900
# MIKE EVANS WR 6900
# KALIF RAYMOND WR 4900
# KEENAN ALLEN WR 7000
# DONALD PARHAM TE 2600
# JAVONTE WILLIAMS RB 5000
#
#
# Lineup 239:
#
# TUA TAGOVAILOA QB 5600
# NYHEIM HINES RB 5000
# DALVIN COOK RB 8000
# AJ BROWN WR 7800
# TERRY MCLAURIN WR 7600
# RUSSELL GAGE WR 5000
# JUWAN JOHNSON TE 2500
# JAYLEN WADDLE WR 5500
#
#
# Lineup 240:
#
# MATT RYAN QB 6000
# DEVIN SINGLETARY RB 4700
# AARON JONES RB 6900
# DEEBO SAMUEL WR 7400
# TYREEK HILL WR 7700
# COREY DAVIS WR 4900
# HAYDEN HURST TE 2800
# DONOVAN PEOPLESJONES WR 4800
#
#
# Lineup 241:
#
# AARON RODGERS QB 7100
# KENNY GAINWELL RB 4700
# JAMES CONNER RB 6300
# ADAM THIELEN WR 6700
# DONOVAN PEOPLESJONES WR 4800
# MIKE EVANS WR 6900
# MARK ANDREWS TE 5700
# ROBBY ANDERSON WR 4400
#
#
# Lineup 242:
#
# BAKER MAYFIELD QB 5400
# ALEX COLLINS RB 5200
# DARRELL HENDERSON RB 6400
# JAMES WASHINGTON WR 3500
# MICHAEL PITTMAN WR 6300
# COOPER KUPP WR 9500
# KYLE PITTS TE 5800
# MIKE GESICKI TE 4900
#
#
# Lineup 243:
#
# RYAN TANNEHILL QB 6200
# NAJEE HARRIS RB 7900
# ANTONIO GIBSON RB 5500
# KEENAN ALLEN WR 7000
# DIONTAE JOHNSON WR 6800
# JAKOBI MEYERS WR 4800
# HARRISON BRYANT TE 2500
# DJ MOORE WR 6300
#
#
# Lineup 244:
#
# JOSH ALLEN QB 7900
# EZEKIEL ELLIOTT RB 7000
# TREY SERMON RB 4300
# SAMMY WATKINS WR 4300
# BRYAN EDWARDS WR 4200
# STEFON DIGGS WR 7500
# TOMMY SWEENEY TE 2600
# DEEBO SAMUEL WR 7400
#
#
# Lineup 245:
#
# MAC JONES QB 5300
# MIKE DAVIS RB 4600
# LEONARD FOURNETTE RB 6100
# CEEDEE LAMB WR 7000
# AJ BROWN WR 7800
# ELIJAH MOORE WR 4700
# TAYSOM HILL TE 5200
# TRAVIS HOMER RB 4500
#
#
# Lineup 246:
#
# MIKE WHITE QB 5100
# ENO BENJAMIN RB 4400
# ELIJAH MITCHELL RB 5700
# KEENAN ALLEN WR 7000
# DONOVAN PEOPLESJONES WR 4800
# MARQUEZ CALLAWAY WR 5100
# DALTON SCHULTZ TE 5000
# JONATHAN TAYLOR RB 8100
#
#
# Lineup 247:
#
# KIRK COUSINS QB 6100
# JEREMY MCNICHOLS RB 5500
# NAJEE HARRIS RB 7900
# MICHAEL PITTMAN WR 6300
# JUSTIN JEFFERSON WR 7700
# KALIF RAYMOND WR 4900
# RICKY SEALSJONES TE 3700
# MIKE GESICKI TE 4900
#
#
# Lineup 248:
#
# RYAN TANNEHILL QB 6200
# DEEJAY DALLAS RB 4100
# DARREL WILLIAMS RB 5400
# JAMISON CROWDER WR 4800
# KEENAN ALLEN WR 7000
# ADAM THIELEN WR 6700
# TAYSOM HILL TE 5200
# KYLE PITTS TE 5800
#
#
# Lineup 249:
#
# DAK PRESCOTT QB 6900
# DEVIN SINGLETARY RB 4700
# NAJEE HARRIS RB 7900
# ROBBY ANDERSON WR 4400
# AJ GREEN WR 4600
# MIKE WILLIAMS WR 6600
# DARREN WALLER TE 6300
# TAYSOM HILL TE 5200
#
#
# Lineup 250:
#
# MATTHEW STAFFORD QB 7000
# CHRISTIAN MCCAFFREY RB 8400
# BOSTON SCOTT RB 4900
# ADAM THIELEN WR 6700
# COREY DAVIS WR 4900
# COURTLAND SUTTON WR 5600
# JUWAN JOHNSON TE 2500
# ALEX COLLINS RB 5200
#
#
# Lineup 251:
#
# MAC JONES QB 5300
# MICHAEL CARTER RB 5600
# ELIJAH MITCHELL RB 5700
# DK METCALF WR 6800
# ADAM THIELEN WR 6700
# ...
# HUNTER HENRY TE 4100
# CORDARRELLE PATTERSON RB 6600
#
#
# Lineup 417:
#
# MATTHEW STAFFORD QB 7000
# JORDAN HOWARD RB 4900
# AUSTIN EKELER RB 7600
# DEEBO SAMUEL WR 7400
# MARQUISE BROWN WR 6700
# NELSON AGHOLOR WR 4000
# GERALD EVERETT TE 2600
# CARLOS HYDE RB 5000
#
#
# Lineup 418:
#
# RUSSELL WILSON QB 6700
# KENNY GAINWELL RB 4700
# ALEXANDER MATTISON RB 4500
# KEENAN ALLEN WR 7000
# CHRIS GODWIN WR 7100
# CEEDEE LAMB WR 7000
# RICKY SEALSJONES TE 3700
# DJ MOORE WR 6300
#
#
# Lineup 419:
#
# DAK PRESCOTT QB 6900
# D'ANDRE SWIFT RB 6800
# ADRIAN PETERSON RB 4900
# AJ BROWN WR 7800
# JAKOBI MEYERS WR 4800
# RANDALL COBB WR 4300
# HUNTER HENRY TE 4100
# CEEDEE LAMB WR 7000
#
#
# Lineup 420:
#
# AARON RODGERS QB 7100
# AUSTIN EKELER RB 7600
# JORDAN HOWARD RB 4900
# COREY DAVIS WR 4900
# JARVIS LANDRY WR 5200
# MICHAEL PITTMAN WR 6300
# DARREN WALLER TE 6300
# TREY SERMON RB 4300
#
#
# Lineup 421:
#
# LAMAR JACKSON QB 7800
# DEVONTA FREEMAN RB 5000
# TRAVIS HOMER RB 4500
# TYREEK HILL WR 7700
# MIKE EVANS WR 6900
# CEDRICK WILSON WR 3500
# TJ HOCKENSON TE 5500
# LEONARD FOURNETTE RB 6100
#
#
# Lineup 422:
#
# BAKER MAYFIELD QB 5400
# GIOVANI BERNARD RB 4300
# AJ DILLON RB 4800
# CEEDEE LAMB WR 7000
# TERRY MCLAURIN WR 7600
# JARVIS LANDRY WR 5200
# MIKE GESICKI TE 4900
# GEORGE KITTLE TE 6000
#
#
# Lineup 423:
#
# RUSSELL WILSON QB 6700
# AUSTIN EKELER RB 7600
# LE'VEON BELL RB 4700
# RONDALE MOORE WR 4400
# ZACH PASCAL WR 4500
# AJ BROWN WR 7800
# DAVID NJOKU TE 3200
# DARREN WALLER TE 6300
#
#
# Lineup 424:
#
# RUSSELL WILSON QB 6700
# BRANDON BOLDEN RB 4400
# NAJEE HARRIS RB 7900
# TYREEK HILL WR 7700
# ELIJAH MOORE WR 4700
# MARQUISE BROWN WR 6700
# DAWSON KNOX TE 4500
# ALLEN LAZARD WR 4400
#
#
# Lineup 425:
#
# DEREK CARR QB 6000
# TONY POLLARD RB 4600
# CHRISTIAN MCCAFFREY RB 8400
# DEVONTA SMITH WR 5900
# HUNTER RENFROW WR 5100
# DJ MOORE WR 6300
# RICKY SEALSJONES TE 3700
# JD MCKISSIC RB 5200
#
#
# Lineup 426:
#
# MAC JONES QB 5300
# EZEKIEL ELLIOTT RB 7000
# CORDARRELLE PATTERSON RB 6600
# MARQUEZ CALLAWAY WR 5100
# RUSSELL GAGE WR 5000
# JERRY JEUDY WR 5300
# JARED COOK TE 3200
# TYREEK HILL WR 7700
#
#
# Lineup 427:
#
# LAMAR JACKSON QB 7800
# TONY POLLARD RB 4600
# DALVIN COOK RB 8000
# JAMISON CROWDER WR 4800
# KALIF RAYMOND WR 4900
# HUNTER RENFROW WR 5100
# ZACH ERTZ TE 4600
# CHUBA HUBBARD RB 5400
#
#
# Lineup 428:
#
# RUSSELL WILSON QB 6700
# ALEX COLLINS RB 5200
# NAJEE HARRIS RB 7900
# STEFON DIGGS WR 7500
# SAMMY WATKINS WR 4300
# MICHAEL PITTMAN WR 6300
# AUSTIN HOOPER TE 2800
# DAWSON KNOX TE 4500
#
#
# Lineup 429:
#
# TEDDY BRIDGEWATER QB 5500
# DALVIN COOK RB 8000
# MARK INGRAM RB 4500
# DEVONTA SMITH WR 5900
# JAKOBI MEYERS WR 4800
# MIKE EVANS WR 6900
# TOMMY TREMBLE TE 2500
# CHRIS GODWIN WR 7100
#
#
# Lineup 430:
#
# COOPER RUSH QB 4800
# MIKE DAVIS RB 4600
# MICHAEL CARTER RB 5600
# COOPER KUPP WR 9500
# AJ BROWN WR 7800
# AMONRA ST BROWN WR 3800
# HARRISON BRYANT TE 2500
# CHRISTIAN MCCAFFREY RB 8400
#
#
# Lineup 431:
#
# JUSTIN HERBERT QB 7300
# MICHAEL CARTER RB 5600
# EZEKIEL ELLIOTT RB 7000
# MIKE WILLIAMS WR 6600
# JAMES WASHINGTON WR 3500
# DEEBO SAMUEL WR 7400
# RICKY SEALSJONES TE 3700
# ANTONIO GIBSON RB 5500
#
#
# Lineup 432:
#
# AARON RODGERS QB 7100
# JEREMY MCNICHOLS RB 5500
# ANTONIO GIBSON RB 5500
# JALEN REAGOR WR 3500
# TIM PATRICK WR 4900
# KEENAN ALLEN WR 7000
# TAYSOM HILL TE 5200
# DAVANTE ADAMS WR 7900
#
#
# Lineup 433:
#
# AARON RODGERS QB 7100
# JAVONTE WILLIAMS RB 5000
# TREY SERMON RB 4300
# DK METCALF WR 6800
# MIKE EVANS WR 6900
# CHRIS GODWIN WR 7100
# ALBERT OKWUEGBUNAM TE 3300
# LEONARD FOURNETTE RB 6100
#
#
# Lineup 434:
#
# MIKE WHITE QB 5100
# JAMES ROBINSON RB 6200
# JORDAN HOWARD RB 4900
# JUSTIN JEFFERSON WR 7700
# TYREEK HILL WR 7700
# ELIJAH MOORE WR 4700
# TJ HOCKENSON TE 5500
# JARVIS LANDRY WR 5200
#
#
# Lineup 435:
#
# TUA TAGOVAILOA QB 5600
# DARRELL HENDERSON RB 6400
# AARON JONES RB 6900
# JAMES WASHINGTON WR 3500
# MICHAEL PITTMAN WR 6300
# CHRIS GODWIN WR 7100
# ADAM TRAUTMAN TE 3000
# AJ BROWN WR 7800
#
#
# Lineup 436:
#
# KIRK COUSINS QB 6100
# TY JOHNSON RB 4500
# JONATHAN TAYLOR RB 8100
# JAMISON CROWDER WR 4800
# STEFON DIGGS WR 7500
# ELIJAH MOORE WR 4700
# DONALD PARHAM TE 2600
# TRAVIS KELCE TE 6900
#
#
# Lineup 437:
#
# MATTHEW STAFFORD QB 7000
# JOSH JACOBS RB 6200
# ENO BENJAMIN RB 4400
# KALIF RAYMOND WR 4900
# KEENAN ALLEN WR 7000
# JUSTIN JEFFERSON WR 7700
# JACK DOYLE TE 3100
# MARQUISE BROWN WR 6700
#
#
# Lineup 438:
#
# AARON RODGERS QB 7100
# JONATHAN TAYLOR RB 8100
# LE'VEON BELL RB 4700
# CEDRICK WILSON WR 3500
# AJ BROWN WR 7800
# DIONTAE JOHNSON WR 6800
# MO ALIECOX TE 3100
# JEREMY MCNICHOLS RB 5500
#
#
# Lineup 439:
#
# MATTHEW STAFFORD QB 7000
# D'ANDRE SWIFT RB 6800
# TRAVIS HOMER RB 4500
# TERRY MCLAURIN WR 7600
# JAMAL AGNEW WR 4500
# BRANDON AIYUK WR 4700
# TAYSOM HILL TE 5200
# MIKE GESICKI TE 4900
#
#
# Lineup 440:
#
# RYAN TANNEHILL QB 6200
# JONATHAN TAYLOR RB 8100
# CHUBA HUBBARD RB 5400
# DEEBO SAMUEL WR 7400
# TYLER LOCKETT WR 6500
# RUSSELL GAGE WR 5000
# DAN ARNOLD TE 3500
# MIKE GESICKI TE 4900
#
#
# Lineup 441:
#
# DEREK CARR QB 6000
# D'ANDRE SWIFT RB 6800
# ELIJAH MITCHELL RB 5700
# TYLER LOCKETT WR 6500
# TY HILTON WR 4700
# BRANDON AIYUK WR 4700
# RICKY SEALSJONES TE 3700
# CHRIS GODWIN WR 7100
#
#
# Lineup 442:
#
# MATTHEW STAFFORD QB 7000
# CHRISTIAN MCCAFFREY RB 8400
# JEFF WILSON RB 5000
# MIKE EVANS WR 6900
# JAKOBI MEYERS WR 4800
# RUSSELL GAGE WR 5000
# JACK DOYLE TE 3100
# CARLOS HYDE RB 5000
#
#
# Lineup 443:
#
# JARED GOFF QB 5200
# D'ANDRE SWIFT RB 6800
# ALEX COLLINS RB 5200
# BRANDON AIYUK WR 4700
# MIKE WILLIAMS WR 6600
# COLE BEASLEY WR 5200
# GEORGE KITTLE TE 6000
# CHRISTIAN KIRK WR 5500
#
#
# Lineup 444:
#
# JUSTIN HERBERT QB 7300
# KENYAN DRAKE RB 5100
# ELIJAH MITCHELL RB 5700
# MIKE EVANS WR 6900
# MARQUISE BROWN WR 6700
# ADAM THIELEN WR 6700
# JUWAN JOHNSON TE 2500
# SAMMY WATKINS WR 4300
#
#
# Lineup 445:
#
# PATRICK MAHOMES QB 7200
# NAJEE HARRIS RB 7900
# DALVIN COOK RB 8000
# MARQUEZ CALLAWAY WR 5100
# QUEZ WATKINS WR 3600
# RASHOD BATEMAN WR 4200
# DARREN WALLER TE 6300
# SONY MICHEL RB 4300
#
#
# Lineup 446:
#
# MATTHEW STAFFORD QB 7000
# CORDARRELLE PATTERSON RB 6600
# NAJEE HARRIS RB 7900
# BRYAN EDWARDS WR 4200
# JARVIS LANDRY WR 5200
# DEEBO SAMUEL WR 7400
# HUNTER HENRY TE 4100
# LAVISKA SHENAULT WR 4600
#
#
# Lineup 447:
#
# CARSON WENTZ QB 5900
# JAVONTE WILLIAMS RB 5000
# DALVIN COOK RB 8000
# ZACH PASCAL WR 4500
# TERRY MCLAURIN WR 7600
# DEEBO SAMUEL WR 7400
# DURHAM SMYTHE TE 2500
# NOAH FANT TE 4300
#
#
# Lineup 448:
#
# TOM BRADY QB 7600
# NAJEE HARRIS RB 7900
# JEFF WILSON RB 5000
# MICHAEL PITTMAN WR 6300
# CEEDEE LAMB WR 7000
# CHRISTIAN KIRK WR 5500
# GERALD EVERETT TE 2600
# KENNY GAINWELL RB 4700
#
#
# Lineup 449:
#
# JOSH ALLEN QB 7900
# KENNY GAINWELL RB 4700
# AARON JONES RB 6900
# OLAMIDE ZACCHEAUS WR 4400
# MARVIN JONES WR 5800
# TY HILTON WR 4700
# DAWSON KNOX TE 4500
# DJ MOORE WR 6300
# Lineup 450:
#
# DEREK CARR QB 6000
# NAJEE HARRIS RB 7900
# JAMES ROBINSON RB 6200
# OLAMIDE ZACCHEAUS WR 4400
# DEEBO SAMUEL WR 7400
# DIONTAE JOHNSON WR 6800
# JACK DOYLE TE 3100
# DONOVAN PEOPLESJONES WR 4800
#
#
# Lineup 451:
#
# TAYLOR HEINICKE QB 5400
# JD MCKISSIC RB 5200
# D'ANDRE SWIFT RB 6800
# KALIF RAYMOND WR 4900
# OLAMIDE ZACCHEAUS WR 4400
# JUSTIN JEFFERSON WR 7700
# TRAVIS KELCE TE 6900
# MELVIN GORDON RB 5300
#
#
# Lineup 452:
#
# PATRICK MAHOMES QB 7200
# JEREMY MCNICHOLS RB 5500
# JAMES CONNER RB 6300
# ADAM HUMPHRIES WR 3500
# KEENAN ALLEN WR 7000
# DK METCALF WR 6800
# PAT FREIERMUTH TE 3900
# JAVONTE WILLIAMS RB 5000
#
#
# Lineup 453:
#
# MAC JONES QB 5300
# GIOVANI BERNARD RB 4300
# ELIJAH MITCHELL RB 5700
# CEEDEE LAMB WR 7000
# AMARI COOPER WR 6200
# HUNTER RENFROW WR 5100
# TYLER HIGBEE TE 4000
# TERRY MCLAURIN WR 7600
#
#
# Lineup 454:
#
# TEDDY BRIDGEWATER QB 5500
# DARRELL HENDERSON RB 6400
# DALVIN COOK RB 8000
# JARVIS LANDRY WR 5200
# AMARI COOPER WR 6200
# MIKE WILLIAMS WR 6600
# TYLER CONKLIN TE 3400
# MARK ANDREWS TE 5700
#
#
# Lineup 455:
#
# TAYLOR HEINICKE QB 5400
# JD MCKISSIC RB 5200
# NAJEE HARRIS RB 7900
# ELIJAH MOORE WR 4700
# MARQUISE BROWN WR 6700
# ADAM HUMPHRIES WR 3500
# TYLER CONKLIN TE 3400
# CHRISTIAN MCCAFFREY RB 8400
#
#
# Lineup 456:
#
# MATT RYAN QB 6000
# AJ DILLON RB 4800
# LEONARD FOURNETTE RB 6100
# JUSTIN JEFFERSON WR 7700
# ELIJAH MOORE WR 4700
# OLAMIDE ZACCHEAUS WR 4400
# TAYSOM HILL TE 5200
# MICHAEL PITTMAN WR 6300
#
#
# Lineup 457:
#
# TAYLOR HEINICKE QB 5400
# ANTONIO GIBSON RB 5500
# D'ERNEST JOHNSON RB 4700
# MIKE EVANS WR 6900
# ADAM THIELEN WR 6700
# JAMISON CROWDER WR 4800
# DALTON SCHULTZ TE 5000
# TERRY MCLAURIN WR 7600
#
#
# Lineup 458:
#
# BAKER MAYFIELD QB 5400
# BRANDON BOLDEN RB 4400
# TONY POLLARD RB 4600
# COOPER KUPP WR 9500
# RUSSELL GAGE WR 5000
# DEEBO SAMUEL WR 7400
# HAYDEN HURST TE 2800
# STEFON DIGGS WR 7500
#
#
# Lineup 459:
#
# TOM BRADY QB 7600
# JOSH JACOBS RB 6200
# DALVIN COOK RB 8000
# RONDALE MOORE WR 4400
# JAYLEN WADDLE WR 5500
# AMARI COOPER WR 6200
# JUWAN JOHNSON TE 2500
# JAMES ROBINSON RB 6200
#
#
# Lineup 460:
#
# BAKER MAYFIELD QB 5400
# D'ANDRE SWIFT RB 6800
# AARON JONES RB 6900
# MIKE EVANS WR 6900
# VAN JEFFERSON WR 4100
# MIKE WILLIAMS WR 6600
# TAYSOM HILL TE 5200
# ELIJAH MOORE WR 4700
#
#
# Lineup 461:
#
# PJ WALKER QB 5000
# EZEKIEL ELLIOTT RB 7000
# ENO BENJAMIN RB 4400
# MARVIN JONES WR 5800
# CHRIS GODWIN WR 7100
# DEEBO SAMUEL WR 7400
# DALLAS GOEDERT TE 4700
# COURTLAND SUTTON WR 5600
#
#
# Lineup 462:
#
# LAMAR JACKSON QB 7800
# ALEX COLLINS RB 5200
# CARLOS HYDE RB 5000
# DONOVAN PEOPLESJONES WR 4800
# MIKE EVANS WR 6900
# CEEDEE LAMB WR 7000
# ZACH ERTZ TE 4600
# EMMANUEL SANDERS WR 5700
#
#
# Lineup 463:
#
# TEDDY BRIDGEWATER QB 5500
# RHAMONDRE STEVENSON RB 4500
# CORDARRELLE PATTERSON RB 6600
# COOPER KUPP WR 9500
# NELSON AGHOLOR WR 4000
# CHRISTIAN KIRK WR 5500
# TAYSOM HILL TE 5200
# JAMES ROBINSON RB 6200
#
#
# Lineup 464:
#
# AARON RODGERS QB 7100
# DARRELL HENDERSON RB 6400
# CORDARRELLE PATTERSON RB 6600
# KENDRICK BOURNE WR 4600
# AMONRA ST BROWN WR 3800
# TERRY MCLAURIN WR 7600
# TYLER HIGBEE TE 4000
# AARON JONES RB 6900
#
#
# Lineup 465:
#
# JALEN HURTS QB 6500
# MELVIN GORDON RB 5300
# CHUBA HUBBARD RB 5400
# DJ MOORE WR 6300
# JARVIS LANDRY WR 5200
# MIKE WILLIAMS WR 6600
# ZACH ERTZ TE 4600
# JERRY JEUDY WR 5300
#
#
# Lineup 466:
#
# LAMAR JACKSON QB 7800
# JONATHAN TAYLOR RB 8100
# JOSH JACOBS RB 6200
# COLE BEASLEY WR 5200
# ALLEN LAZARD WR 4400
# MIKE WILLIAMS WR 6600
# PAT FREIERMUTH TE 3900
# BRANDON BOLDEN RB 4400
#
#
# Lineup 467:
#
# BAKER MAYFIELD QB 5400
# EZEKIEL ELLIOTT RB 7000
# MIKE DAVIS RB 4600
# DEEBO SAMUEL WR 7400
# LAVISKA SHENAULT WR 4600
# MIKE EVANS WR 6900
# NOAH FANT TE 4300
# DARRELL HENDERSON RB 6400
#
#
# Lineup 468:
#
# JALEN HURTS QB 6500
# AARON JONES RB 6900
# CHRISTIAN MCCAFFREY RB 8400
# ZACH PASCAL WR 4500
# ADAM THIELEN WR 6700
# JAMISON CROWDER WR 4800
# MIKE GESICKI TE 4900
# TREY SERMON RB 4300
#
#
# Lineup 469:
#
# AARON RODGERS QB 7100
# KENNY GAINWELL RB 4700
# TY JOHNSON RB 4500
# MARQUEZ CALLAWAY WR 5100
# MIKE EVANS WR 6900
# DEEBO SAMUEL WR 7400
# TAYSOM HILL TE 5200
# ELIJAH MITCHELL RB 5700
#
#
# Lineup 470:
#
# DAK PRESCOTT QB 6900
# AJ DILLON RB 4800
# D'ANDRE SWIFT RB 6800
# TAJAE SHARPE WR 3900
# MIKE EVANS WR 6900
# CHRIS GODWIN WR 7100
# IAN THOMAS TE 2500
# JUSTIN JEFFERSON WR 7700
#
#
# Lineup 471:
#
# LAMAR JACKSON QB 7800
# JORDAN HOWARD RB 4900
# CORDARRELLE PATTERSON RB 6600
# CHRISTIAN KIRK WR 5500
# MIKE EVANS WR 6900
# JAKOBI MEYERS WR 4800
# OJ HOWARD TE 2700
# AJ BROWN WR 7800
#
#
# Lineup 472:
#
# RYAN TANNEHILL QB 6200
# JD MCKISSIC RB 5200
# JOSH JACOBS RB 6200
# LAVISKA SHENAULT WR 4600
# DIONTAE JOHNSON WR 6800
# TYREEK HILL WR 7700
# DALTON SCHULTZ TE 5000
# JERRY JEUDY WR 5300
#
#
# Lineup 473:
#
# DAK PRESCOTT QB 6900
# DALVIN COOK RB 8000
# ELIJAH MITCHELL RB 5700
# DK METCALF WR 6800
# AJ GREEN WR 4600
# STEFON DIGGS WR 7500
# ALBERT OKWUEGBUNAM TE 3300
# JALEN RICHARD RB 4200
#
#
# Lineup 474:
#
# JUSTIN HERBERT QB 7300
# JAVONTE WILLIAMS RB 5000
# ANTONIO GIBSON RB 5500
# CHRIS GODWIN WR 7100
# TIM PATRICK WR 4900
# MARQUISE BROWN WR 6700
# DAWSON KNOX TE 4500
# JALEN RICHARD RB 4200
#
#
# Lineup 475:
#
# PATRICK MAHOMES QB 7200
# AUSTIN EKELER RB 7600
# ADRIAN PETERSON RB 4900
# JERRY JEUDY WR 5300
# AMARI COOPER WR 6200
# STEFON DIGGS WR 7500
# DAN ARNOLD TE 3500
# JAKOBI MEYERS WR 4800
#
#
# Lineup 476:
#
# RYAN TANNEHILL QB 6200
# ALEXANDER MATTISON RB 4500
# AUSTIN EKELER RB 7600
# JAYLEN WADDLE WR 5500
# JAMAL AGNEW WR 4500
# CEEDEE LAMB WR 7000
# TRAVIS KELCE TE 6900
# BRANDON BOLDEN RB 4400
#
#
# Lineup 477:
#
# JOSH ALLEN QB 7900
# JAMES CONNER RB 6300
# GIOVANI BERNARD RB 4300
# TERRY MCLAURIN WR 7600
# KENDRICK BOURNE WR 4600
# MIKE WILLIAMS WR 6600
# WILL DISSLY TE 2500
# DK METCALF WR 6800
#
#
# Lineup 478:
#
# BAKER MAYFIELD QB 5400
# DARRELL HENDERSON RB 6400
# AUSTIN EKELER RB 7600
# JAMISON CROWDER WR 4800
# JAYLEN WADDLE WR 5500
# KALIF RAYMOND WR 4900
# TYLER HIGBEE TE 4000
# MIKE WILLIAMS WR 6600
#
#
# Lineup 479:
#
# TUA TAGOVAILOA QB 5600
# MELVIN GORDON RB 5300
# CORDARRELLE PATTERSON RB 6600
# DEONTE HARRIS WR 4000
# ADAM THIELEN WR 6700
# EMMANUEL SANDERS WR 5700
# TRAVIS KELCE TE 6900
# JOSH JACOBS RB 6200
#
#
# Lineup 480:
#
# TREVOR SIEMIAN QB 5200
# JEFF WILSON RB 5000
# JEREMY MCNICHOLS RB 5500
# MICHAEL PITTMAN WR 6300
# DK METCALF WR 6800
# DJ MOORE WR 6300
# IAN THOMAS TE 2500
# AUSTIN EKELER RB 7600
#
#
# Lineup 481:
#
# CARSON WENTZ QB 5900
# DALVIN COOK RB 8000
# DEVIN SINGLETARY RB 4700
# MARQUISE BROWN WR 6700
# CEDRICK WILSON WR 3500
# COURTLAND SUTTON WR 5600
# DAWSON KNOX TE 4500
# TYREEK HILL WR 7700
#
#
# Lineup 482:
#
# KIRK COUSINS QB 6100
# CHRISTIAN MCCAFFREY RB 8400
# TY JOHNSON RB 4500
# JAYLEN WADDLE WR 5500
# VAN JEFFERSON WR 4100
# KALIF RAYMOND WR 4900
# TJ HOCKENSON TE 5500
# TERRY MCLAURIN WR 7600
#
#
# Lineup 483:
#
# TOM BRADY QB 7600
# NAJEE HARRIS RB 7900
# CHUBA HUBBARD RB 5400
# BRANDON AIYUK WR 4700
# JARVIS LANDRY WR 5200
# TYLER LOCKETT WR 6500
# TOMMY SWEENEY TE 2600
# ADAM THIELEN WR 6700
#
#
# Lineup 484:
#
# LAMAR JACKSON QB 7800
# AUSTIN EKELER RB 7600
# NYHEIM HINES RB 5000
# DONOVAN PEOPLESJONES WR 4800
# RONDALE MOORE WR 4400
# ELIJAH MOORE WR 4700
# DARREN WALLER TE 6300
# TONY POLLARD RB 4600
#
#
# Lineup 485:
#
# MIKE WHITE QB 5100
# DARREL WILLIAMS RB 5400
# AUSTIN EKELER RB 7600
# HUNTER RENFROW WR 5100
# EMMANUEL SANDERS WR 5700
# MICHAEL GALLUP WR 4000
# GEORGE KITTLE TE 6000
# JONATHAN TAYLOR RB 8100
#
#
# Lineup 486:
#
# TAYLOR HEINICKE QB 5400
# LEONARD FOURNETTE RB 6100
# JOSH JACOBS RB 6200
# TYLER LOCKETT WR 6500
# TYREEK HILL WR 7700
# HUNTER RENFROW WR 5100
# JUWAN JOHNSON TE 2500
# STEFON DIGGS WR 7500
#
#
# Lineup 487:
#
# MATTHEW STAFFORD QB 7000
# JORDAN HOWARD RB 4900
# DARREL WILLIAMS RB 5400
# OLAMIDE ZACCHEAUS WR 4400
# CHRISTIAN KIRK WR 5500
# CEEDEE LAMB WR 7000
# GEORGE KITTLE TE 6000
# DK METCALF WR 6800
#
#
# Lineup 488:
#
# PJ WALKER QB 5000
# MIKE DAVIS RB 4600
# JAMES ROBINSON RB 6200
# JUSTIN JEFFERSON WR 7700
# DIONTAE JOHNSON WR 6800
# AJ GREEN WR 4600
# TJ HOCKENSON TE 5500
# AJ DILLON RB 4800
#
#
# Lineup 489:
#
# CASE KEENUM QB 4900
# JD MCKISSIC RB 5200
# AJ DILLON RB 4800
# COOPER KUPP WR 9500
# JALEN GUYTON WR 3600
# EMMANUEL SANDERS WR 5700
# TRAVIS KELCE TE 6900
# MIKE DAVIS RB 4600
#
#
# Lineup 490:
#
# TAYLOR HEINICKE QB 5400
# CORDARRELLE PATTERSON RB 6600
# LEONARD FOURNETTE RB 6100
# JAMISON CROWDER WR 4800
# MIKE WILLIAMS WR 6600
# DONOVAN PEOPLESJONES WR 4800
# TAYSOM HILL TE 5200
# EMMANUEL SANDERS WR 5700
#
#
# Lineup 491:
#
# JARED GOFF QB 5200
# TREY SERMON RB 4300
# CHRISTIAN MCCAFFREY RB 8400
# TERRY MCLAURIN WR 7600
# ELIJAH MOORE WR 4700
# DEEBO SAMUEL WR 7400
# DAWSON KNOX TE 4500
# KALIF RAYMOND WR 4900
#
#
# Lineup 492:
#
# JACOBY BRISSETT QB 5100
# D'ANDRE SWIFT RB 6800
# LEONARD FOURNETTE RB 6100
# ALLEN LAZARD WR 4400
# CHRIS GODWIN WR 7100
# DEVONTA SMITH WR 5900
# TRAVIS KELCE TE 6900
# LE'VEON BELL RB 4700
# Lineup 493:
#
# CASE KEENUM QB 4900
# KENNY GAINWELL RB 4700
# D'ANDRE SWIFT RB 6800
# COURTLAND SUTTON WR 5600
# AJ BROWN WR 7800
# TIM PATRICK WR 4900
# TRAVIS KELCE TE 6900
# CHUBA HUBBARD RB 5400
#
#
# Lineup 494:
#
# DEREK CARR QB 6000
# CARLOS HYDE RB 5000
# D'ANDRE SWIFT RB 6800
# MIKE WILLIAMS WR 6600
# AMONRA ST BROWN WR 3800
# DEEBO SAMUEL WR 7400
# DAN ARNOLD TE 3500
# NAJEE HARRIS RB 7900
#
#
# Lineup 495:
#
# RUSSELL WILSON QB 6700
# RHAMONDRE STEVENSON RB 4500
# LEONARD FOURNETTE RB 6100
# MIKE EVANS WR 6900
# TIM PATRICK WR 4900
# ADAM THIELEN WR 6700
# ZACH ERTZ TE 4600
# AJ DILLON RB 4800
#
#
# Lineup 496:
#
# JIMMY GAROPPOLO QB 5500
# DARREL WILLIAMS RB 5400
# MELVIN GORDON RB 5300
# AJ BROWN WR 7800
# CEDRICK WILSON WR 3500
# JAYLEN WADDLE WR 5500
# MARK ANDREWS TE 5700
# NAJEE HARRIS RB 7900
#
#
# Lineup 497:
#
# TOM BRADY QB 7600
# KENYAN DRAKE RB 5100
# JEREMY MCNICHOLS RB 5500
# ADAM THIELEN WR 6700
# AMONRA ST BROWN WR 3800
# TERRY MCLAURIN WR 7600
# ZACH ERTZ TE 4600
# LEONARD FOURNETTE RB 6100
#
#
# Lineup 498:
#
# DAK PRESCOTT QB 6900
# ZACK MOSS RB 5100
# D'ANDRE SWIFT RB 6800
# JUSTIN JEFFERSON WR 7700
# CHRIS GODWIN WR 7100
# JAMISON CROWDER WR 4800
# JACK DOYLE TE 3100
# JEREMY MCNICHOLS RB 5500
#
#
# Lineup 499:
#
# MATTHEW STAFFORD QB 7000
# ELIJAH MITCHELL RB 5700
# BRANDON BOLDEN RB 4400
# JARVIS LANDRY WR 5200
# CEEDEE LAMB WR 7000
# TY HILTON WR 4700
# NOAH FANT TE 4300
# MIKE EVANS WR 6900
#
#
# AVG LINEUP SCORE OF INIT POPULATION: 95.87864000000002

# %%
# Define the fitness function
def fitness(lineup):
    lineup_rating = 0
    
    # is this lineup stacking a QB & a WR/TE?
    # or inverted stacking which means a QB and a member of 
    # the opposing teams passing game
    QB_team = str(lineup[0]["TEAM"])
    s_count = 0
    inv_count = 0
    
    for player in lineup:
        # check for stack
        if player["POS"] == "WR" or player["POS"] == "TE":
            if player["TEAM"] == QB_team:
                s_count += 1
            if player["OPP"] == QB_team:
                inv_count += 1
                
        # add base rating to lineup
        lineup_rating += player["RTG"]
        # factor in home/away
        if player["h/a"] == "home":
            lineup_rating += 2
        else:
            lineup_rating -= 2
        
        # factor in matchup (def_rtg)
        def_rtg = player["DEF_RTG"]
        lineup_rating += def_rtg
        
    # factor in stack_coeffecient
    if s_count == 1:
        lineup_rating += 10
    if s_count > 1:
        lineup_rating -= ((s_count-1)*5)
    if inv_count == 1:
        lineup_rating += 4
    if inv_count == 2:
        lineup_rating += 0
    if inv_count <= 3:
        lineup_rating -= (4*(inv_count-2))
        
    # never take a tightend at flex
    if lineup[7]["POS"] == "TE":
        lineup_rating -= 20
    # prefer wide recievers
    if lineup[7]["POS"] == "WR":
        lineup_rating += 2
        
    return lineup_rating

# %%
# Define the tournament selection function
def tournament_selection(population, fitness_scores, tournament_size):
    selected = []
    for i in range(tournament_size):
        tournament = random.sample(range(len(population)), tournament_size)
        winner = tournament[0]
        for j in tournament:
            if fitness_scores[j] > fitness_scores[winner]:
                winner = j
        selected.append(population[winner])
    return selected

# Define the mutation function
def mutation(lineup, mutation_rate):
    while True:
        mutated = []
        
        # QB
        if random.random() < mutation_rate:
            mutated.append(qb.iloc[random.randint(0, len(qb)-1)])
        else:
            mutated.append(lineup[0])
            
        # RB
        if random.random() < mutation_rate:
            rb1 = rb.iloc[random.randint(0, len(rb)-1)]
            while rb1.equals(lineup[2]) or rb1.equals(lineup[7]): 
                rb1 = rb.iloc[random.randint(0, len(rb)-1)]
            mutated.append(rb1)
        else:
            rb1 = lineup[1]
            mutated.append(rb1)
        if random.random() < mutation_rate:
            rb2 = rb.iloc[random.randint(0, len(rb)-1)]
            while rb2.equals(rb1) or rb2.equals(lineup[7]): 
                rb2 = rb.iloc[random.randint(0, len(rb)-1)]
            mutated.append(rb2)
        else:
            rb2 = lineup[2]
            mutated.append(rb2)
            
        # WR
        if random.random() < mutation_rate:
            wr1 = wr.iloc[random.randint(0, len(wr)-1)]
            while wr1.equals(lineup[4]) or wr1.equals(lineup[5]) or wr1.equals(lineup[7]): 
                wr1 = wr.iloc[random.randint(0, len(wr)-1)]
            mutated.append(wr1)
        else:
            wr1 = lineup[3]
            mutated.append(lineup[3])
        if random.random() < mutation_rate:
            wr2 = wr.iloc[random.randint(0, len(wr)-1)]
            while wr2.equals(wr1) or wr2.equals(lineup[5]) or wr2.equals(lineup[7]):
                wr2 = wr.iloc[random.randint(0, len(wr)-1)]
            mutated.append(wr2)
        else:
            wr2 = lineup[4]
            mutated.append(lineup[4])
        if random.random() < mutation_rate:
            wr3 = wr.iloc[random.randint(0, len(wr)-1)]
            while wr3.equals(wr1) or wr3.equals(wr2) or wr3.equals(lineup[7]):
                wr3 = wr.iloc[random.randint(0, len(wr)-1)]
            mutated.append(wr3)
        else:
            wr3 = lineup[5]
            mutated.append(lineup[5])
        if random.random() < mutation_rate:
            te1 = te.iloc[random.randint(0, len(te)-1)]
            while te1.equals(lineup[7]):
                te1 = te.iloc[random.randint(0, len(te)-1)]
            mutated.append(te1)
        else:
            te1 = lineup[6]
            mutated.append(lineup[6])
        if random.random() < mutation_rate:
            rb_wr_te = flex.iloc[random.randint(0, len(flex)-1)]
            while rb_wr_te.equals(rb1) or rb_wr_te.equals(rb2) or rb_wr_te.equals(wr1) or rb_wr_te.equals(wr2) or rb_wr_te.equals(wr3) or rb_wr_te.equals(te1):
                rb_wr_te = flex.iloc[random.randint(0, len(flex)-1)]
            mutated.append(rb_wr_te)
        else:
            mutated.append(lineup[7])

        tot = sum(player["DK salary"] for player in mutated)
        if tot <= 47000 and tot >= 45000:
            break

    return mutated

# Define the replacement function
def replace_population(population, offspring):
    new_population = population.copy()
    new_population.sort(key=lambda x: fitness(x), reverse=True)
    for i in range(len(offspring)):
        new_population[-(i+1)] = offspring[i]
    return new_population

def sort_population_by_fitness(population, fitness_scores):
    """Sort the population and fitness scores in descending order based on fitness score."""
    sorted_indices = sorted(range(len(fitness_scores)), key=lambda k: fitness_scores[k], reverse=True)
    return [population[i] for i in sorted_indices], [fitness_scores[i] for i in sorted_indices]

def get_top_n_individuals(population, fitness_scores, n):
    """Return the top n individuals and their corresponding fitness scores."""
    P_sorted, F_sorted = sort_population_by_fitness(population, fitness_scores)
    return P_sorted[:n], F_sorted[:n]

# %% [markdown]
# ## RUN ALGORITHM

# %%
for i in range(N_ITERATIONS):
    # eval fitness
    fitness_scores = [fitness(lineup) for lineup in population]
    
    # selection
    selected = tournament_selection(population, fitness_scores, TOURNAMENT_SIZE)

    # Mutation
    offspring = []
    for i in range(0, len(selected)):
        child = mutation(selected[i], MUTATION_RATE)
        offspring.append(child)
    
    # Replace the old population with the new offspring
    population = replace_population(population, offspring)

# best lineups selected
fitness_scores = [fitness(lineup) for lineup in population]
P_sorted, F_sorted = sort_population_by_fitness(population, fitness_scores)
top_n_individuals = P_sorted[:10]
top_n_fitness_scores = F_sorted[:10]

# %% [markdown]
# ## Optimal Lineups

# %%
# print final selected lineups
print("final selected lineups:")
print()
total_points = 0
for j in range(0,len(top_n_individuals)):
    total = 0
    points = 0
    print("lineup " + str(j+1))
    for k in range(0,8):
        s = top_n_individuals[j][k][0]
        sal = top_n_individuals[j][k][7]
        p = round(top_n_individuals[j][k][8], 2)
        name = s.ljust(25)
        p_s = str(p).ljust(6)
        print(top_n_individuals[j][k][1], end = ' ')
        print(name, end = ' ')
        print(str(top_n_individuals[j][k][2]).rjust(3), end = ' ')
        print(sal, end = ' ')
        print(p_s)
        total += int(sal)
        points += p
    print("total salary:", end = '                   ')
    print(total)
    print("total points:", end = '                    ')
    x = (47000-total)/400
    points += x
    print(str(round(points,2)).rjust(10))
    total_points += points
    print()

print("avg points of selected lineups")
print(total_points/10)
# Out:
# final selected lineups:
#
# lineup 1
# QB TUA TAGOVAILOA            MIA 5600 12.32
# RB KENYAN DRAKE               LV 5100 5.1
# RB JONATHAN TAYLOR           IND 8100 27.6
# WR COLE BEASLEY              BUF 5200 3.5
# WR CEEDEE LAMB               DAL 7000 28.6
# WR RANDALL COBB               GB 4300 5.1
# TE MIKE GESICKI              MIA 4900 0.0
# WR DIONTAE JOHNSON           PIT 6800 14.3
# total salary:                   47000
# total points:                         96.52
#
# lineup 2
# QB DAK PRESCOTT              DAL 6900 26.34
# RB JOSH JACOBS                LV 6200 8.6
# RB DALVIN COOK               MIN 8000 20.8
# WR MIKE WILLIAMS             LAC 6600 7.3
# WR CEDRICK WILSON            DAL 3500 0.0
# WR HUNTER RENFROW             LV 5100 17.6
# TE DONALD PARHAM             LAC 2600 2.7
# RB JONATHAN TAYLOR           IND 8100 27.6
# total salary:                   47000
# total points:                        110.94
#
# lineup 3
# QB TUA TAGOVAILOA            MIA 5600 12.32
# RB LE'VEON BELL              BAL 4700 0.1
# RB EZEKIEL ELLIOTT           DAL 7000 21.76
# WR LAVISKA SHENAULT          JAX 4600 5.1
# WR HUNTER RENFROW             LV 5100 17.6
# WR DIONTAE JOHNSON           PIT 6800 14.3
# TE MIKE GESICKI              MIA 4900 0.0
# RB NAJEE HARRIS              PIT 7900 20.3
# total salary:                   46600
# total points:                         92.48
#
# lineup 4
# QB TUA TAGOVAILOA            MIA 5600 12.32
# RB LE'VEON BELL              BAL 4700 0.1
# RB EZEKIEL ELLIOTT           DAL 7000 21.76
# WR LAVISKA SHENAULT          JAX 4600 5.1
# WR HUNTER RENFROW             LV 5100 17.6
# WR DIONTAE JOHNSON           PIT 6800 14.3
# TE MIKE GESICKI              MIA 4900 0.0
# RB NAJEE HARRIS              PIT 7900 20.3
# total salary:                   46600
# total points:                         92.48
#
# lineup 5
# QB DEREK CARR                 LV 6000 19.24
# RB AUSTIN EKELER             LAC 7600 14.9
# RB KENYAN DRAKE               LV 5100 5.1
# WR MIKE EVANS                 TB 6900 14.2
# WR MICHAEL GALLUP            DAL 4000 7.2
# WR EMMANUEL SANDERS          BUF 5700 7.1
# TE DARREN WALLER              LV 6300 6.4
# RB NYHEIM HINES              IND 5000 4.9
# total salary:                   46600
# total points:                         80.04
#
# lineup 6
# QB DEREK CARR                 LV 6000 19.24
# RB AUSTIN EKELER             LAC 7600 14.9
# RB KENYAN DRAKE               LV 5100 5.1
# WR MIKE EVANS                 TB 6900 14.2
# WR MICHAEL GALLUP            DAL 4000 7.2
# WR EMMANUEL SANDERS          BUF 5700 7.1
# TE DARREN WALLER              LV 6300 6.4
# RB NYHEIM HINES              IND 5000 4.9
# total salary:                   46600
# total points:                         80.04
#
# lineup 7
# QB DAK PRESCOTT              DAL 6900 26.34
# RB D'ANDRE SWIFT             DET 6800 19.5
# RB NAJEE HARRIS              PIT 7900 20.3
# WR COOPER KUPP               LAR 9500 26.2
# WR MARQUEZ VALDESSCANTLING    GB 3500 5.1
# WR CEDRICK WILSON            DAL 3500 0.0
# TE JARED COOK                LAC 3200 2.0
# RB MELVIN GORDON             DEN 5300 10.3
# total salary:                   46600
# total points:                        110.74
#
# lineup 8
# QB DAK PRESCOTT              DAL 6900 26.34
# RB DARRELL HENDERSON         LAR 6400 8.1
# RB DARREL WILLIAMS            KC 5400 32.4
# WR CEEDEE LAMB               DAL 7000 28.6
# WR MICHAEL PITTMAN           IND 6300 12.1
# WR MIKE WILLIAMS             LAC 6600 7.3
# TE NOAH FANT                 DEN 4300 10.9
# WR VAN JEFFERSON             LAR 4100 8.4
# total salary:                   47000
# total points:                        134.14
#
# lineup 9
# QB DAK PRESCOTT              DAL 6900 26.34
# RB ELIJAH MITCHELL            SF 5700 9.1
# RB JOSH JACOBS                LV 6200 8.6
# WR COOPER KUPP               LAR 9500 26.2
# WR TIM PATRICK               DEN 4900 4.4
# WR MICHAEL GALLUP            DAL 4000 7.2
# TE TYLER HIGBEE              LAR 4000 11.0
# WR MARVIN JONES              JAX 5800 5.5
# total salary:                   47000
# total points:                         98.34
#
# lineup 10
# QB JUSTIN HERBERT            LAC 7300 13.0
# RB EZEKIEL ELLIOTT           DAL 7000 21.76
# RB AARON JONES                GB 6900 12.6
# WR JALEN GUYTON              LAC 3600 0.0
# WR MICHAEL PITTMAN           IND 6300 12.1
# WR VAN JEFFERSON             LAR 4100 8.4
# TE TRAVIS KELCE               KC 6900 22.9
# RB ADRIAN PETERSON           TEN 4900 3.0
# total salary:                   47000
# total points:                         93.76
#
# avg points of selected lineups
# 98.94800000000001
